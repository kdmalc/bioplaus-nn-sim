# %%
from scipy.integrate import odeint, solve_ivp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

COLOR = 'white'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR

# %% [markdown]
# # Week of 6/21
# Start embedding your model understanding into computational frameworks. So as an exercise, take a stab at implementing the Hodgkin Huxley model for numerical solution, e.g. using scipy (odeint or newer methods).
#
# ## Hodgkin-Huxley Model

# %%
def plot_vnmh(x,t,vertIndex=-1):
    '''
    Callable function for plotting V,n,m,h
    
    Params:
        x: Matrix, each column is one of the above variables
        t: Time vector for x axis
    '''
    
    #plot the results
    plt.figure(figsize=(15,10))
    #Font sizes
    title_font = 20
    label_font = 15

    #Trying to stop them overlapping:
    #fig, ax = plt.subplots(2,1) #--> fig overwrites so I am no longer working on the subplots
    #fig.tight_layout(h_pad=2)
    #fig.suptitle('Overall Title')
    
    #Extract variables from matrix
    if x.shape[1] == 4:
        V = x[:,0]
        n = x[:,1]
        m = x[:,2]
        h = x[:,3]
        
        plt.subplot(211)
        plt.title("Voltage as a Function of Time", fontsize=title_font, fontweight="bold")
        plt.ylabel("Volts (mV)", fontsize=label_font)
        plt.xlabel("Time (ms)", fontsize=label_font)
        plt.plot(t,V)
        
        plt.subplot(212)
        plt.title("Gating Variables as a Function of Time", fontsize=title_font, fontweight="bold")
        plt.ylabel("Volts (mV)", fontsize=label_font)
        plt.xlabel("Time (ms)", fontsize=label_font)
        plt.plot(t,n,label="n")
        plt.plot(t,m,label="m")
        plt.plot(t,h,label="h")
        leg = plt.legend(loc='upper right')
        for text in leg.get_texts():
            text.set_color('black')
        plt.show()
        
    elif x.shape[0] == 10:
        V1 = x[0]
        n1 = x[1]
        m1 = x[2]
        h1 = x[3]
        s1 = x[4]
        V2 = x[5]
        n2 = x[6]
        m2 = x[7]
        h2 = x[8]
        s2 = x[9]
            
        plt.subplot(211)
        plt.title("Voltage as a Function of Time", fontsize=title_font, fontweight="bold")
        plt.ylabel("Volts (mV)", fontsize=label_font)
        plt.xlabel("Time (ms)", fontsize=label_font)
        plt.plot(t,V1,label="Neuron 1")
        plt.plot(t,V2,label="Neuron 2")
        if (vertIndex < 0):
            pass
        else:
            plt.axvline(x = vertIndex, color = 'r', label = 'Index Above Threshold')
        leg = plt.legend(loc='upper right')
        for text in leg.get_texts():
            text.set_color('black')
        plt.show()
        
        plt.subplot(212)
        plt.title("Gating Variables as a Function of Time", fontsize=title_font, fontweight="bold")
        plt.ylabel("Volts (mV)", fontsize=label_font)
        plt.xlabel("Time (ms)", fontsize=label_font)
        plt.plot(t,n1,label="n1")
        plt.plot(t,m1,label="m1")
        plt.plot(t,h1,label="h1")
        plt.plot(t,n2,label="n2")
        plt.plot(t,m2,label="m2")
        plt.plot(t,h2,label="h2")
        leg = plt.legend(loc='upper right')
        for text in leg.get_texts():
            text.set_color('black')
        plt.show()

# %%
def odes(x0,t,I,vI):
    '''
    Defines the constants and differential equations for the base Hodgkin-Huxley equations
    
    Params:: 
        x0: ICs for V,n,m,h
        t: time vector, not called in func but regardless
        I: custom function, time varying current (square wave)
        vI: custom 3x1 vector for I function, just encapsulates the parameters needed for I to function
        
    Returns:: Differential equations of each variable as a vector
    '''
    
    #set ICs
    V = x0[0]
    n = x0[1]
    m = x0[2]
    h = x0[3]
    
    #Constants
    #Source: https://www.math.mcgill.ca/gantumur/docs/reps/RyanSicilianoHH.pdf
    #conductances (S is Siemens)
    gbarNa = 1.2 #mS/cm2
    gNa = gbarNa*(m**3)*h
    gbarK = 0.36 #mS/cm2
    gK = gbarK*(n**4)
    gbarL = 0.003 #mS/cm2
    gL = gbarL
    
    #reversal potentials
    ENa = 55.17 #mV
    EK = -72.14 #mV
    EL = -49.42 #mV
    #membrane capacitance
    Cm = 0.01 #uF/cm^2
    #Alpha and beta forms
    alpha_n = 0.01*(V+50)/(1-np.exp(-(V+50)/10))
    beta_n = 0.125*np.exp(-(V+60)/80)
    alpha_m = 0.1*(V+35)/(1-np.exp(-(V+35)/10))
    beta_m = 4.0*np.exp(-0.0556*(V+60))
    alpha_h = 0.07*np.exp(-0.05*(V+60))
    beta_h = 1/(1+np.exp(-0.1*(V+30)))

    #define each ODE
    dVdt = (1/Cm)*(gNa*(ENa-V) + gK*(EK-V) + gL*(EL-V) + I(t,vI))
    #dVdt = (gNa*(ENa-V) + gK*(EK-V) + gL*(EL-V) + I(t,vI))
    dndt = alpha_n*(1-n)-beta_n*n
    dmdt = alpha_m*(1-m)-beta_m*m
    dhdt = alpha_h*(1-h)-beta_h*h

    return dVdt, dndt, dmdt, dhdt

# %%
def I(t=0,vI=[0,0,0]):
    '''
    Determines the applied current, with respect to the HH model.  By default makes a square wave
    '''
    
    #Applied current
    t_start = vI[0]
    t_end = vI[1]
    amplitude = vI[2]
    
    applied_current = (t>=t_start)*(t<=t_end)*amplitude
    #Ie if t is within range [t_start,t_end], we apply some amount of current, amplitude
    #Recall: t>=C evaluates to a Boolean, which, when used numerically, is equivalent to 0 or 1
    return applied_current

# %%
def burn_in(x0, t):
    '''
    Generates the initial conditions by starting at "accepted" values and then "burning in" until we have values with no temporal dependence
    
    Params: 
        x0: ICs for V,n,m,h
        t: time vector, not sure if this is actually needed (not called in func) 
    '''
    
    #By not specifying vI, vI is set to a vector of zeros, ie no applied current fr the burn in run
    x = odeint(odes,x0,t,args=(I,vI))
    print("Burn in plot: ensure that by end of time interval, the values have reached steady state")
    plot_vnmh(x,t)
    return x

def burn_in_scn(x0, t):
    #This needs to be updated to include vI_scn, as g is passed in through this vector in odes_scn
    '''
    Generates the initial conditions by starting at "accepted" values and then "burning in" until we have values with no temporal dependence
    
    Params: 
        x0: ICs for V,n,m,h
        t: time vector, not sure if this is actually needed (not called in func) 
    '''
    
    #By not specifying vI, vI is set to a vector of zeros, ie no applied current fr the burn in run
    x = odeint(odes_scn,x0,t,args=(I,vI))
    print("Burn in plot: ensure that by end of time interval, the values have reached steady state")
    plot_vnmh(x,t)
    return x

# %% [markdown]
# BURN IN: instead of using the random, clean x0 initial conditions I found, we should use burn in to find what the true steady state of our system is.  I.e. let it run for a really long time and whatever it equilibriates to is what we will use for "true" SS going forward:

# %%
#initial condition: V, n, m, h
x0 = [-58, 0.05, 0.33, 0.6] #Found online... not sure if these are correct
#time vector
t = np.linspace(0,50,2000) #600
#vector needed 
vI = [0,0,0]

x = burn_in(x0, t) #odeint(odes,x0,t,args=(I,vI))

V = x[:,0]
n = x[:,1]
m = x[:,2]
h = x[:,3]
# Out:
# Burn in plot: ensure that by end of time interval, the values have reached steady state

# %%
print("Comparing our original x0 to what our system of differntial equations seems to prefer as SS:")
print(x0)
x0_new = x[-1,:]
print(x0_new)
# Out:
# Comparing our original x0 to what our system of differntial equations seems to prefer as SS:
# [-58, 0.05, 0.33, 0.6]
# [-6.00470736e+01  3.16944630e-01  5.26385829e-02  5.97749949e-01]

# %%
#BURNED IN initial condition
#time vector
t = np.linspace(0,15,1000)
x = odeint(odes,x0_new,t,args=(I,vI))

V = x[:,0]
n = x[:,1]
m = x[:,2]
h = x[:,3]

plot_vnmh(x,t)

# %%
t = np.linspace(0,30,1000) #ms
#NOW SETTING vI to something realistic:
vI = [5,7,0.1]

x = odeint(odes,x0_new,t,args=(I,vI))

V = x[:,0]
n = x[:,1]
m = x[:,2]
h = x[:,3]

plot_vnmh(x,t)

# %% [markdown]
# ## Tasks Post 6/23 Meeting:
# 2. SYNAPTICALLY COUPLED NEURONS: Choose the reversal potential to be the same as the sodium current (Excitatory synapse)
# 3. Start with synpatic g of 0 to verify
# 4. Then begin increasing both g's --> numerically find some minimal set of g's, FIND SUSTAINED OSCILLATION OF CONTINUOUS SPIKING

# %%
def odes_scn(x0,t,I,vI_scn):
    '''
    Defines the constants and differential equations for the HH-compliant synaptically coupled neurons.
    
    Params:: 
        x0: ICs for V1,n1,m1,h1,s1,V2,n2,m2,h2,s2
        t: time vector, not sure if this is actually needed (not called in func)
        I: custom function, time varying current (square wave)
        vI_scn: custom 5x1 vector for I function, just encapsulates the parameters needed for I to function.  
          Also encapsulates the values for g1 and g2
        
    Returns:: Differential equations of each variable as a vector
    
    '''
        
    #set ICs
    V1 = x0[0]
    n1 = x0[1]
    m1 = x0[2]
    h1 = x0[3]
    s1 = x0[4]
    
    V2 = x0[5]
    n2 = x0[6]
    m2 = x0[7]
    h2 = x0[8]
    s2 = x0[9]
        
    #Constants
    #Source: https://www.math.mcgill.ca/gantumur/docs/reps/RyanSicilianoHH.pdf
    
    #conductances (S is Siemens)
    gbarNa = 1.2 #mS/cm2
    gNa1 = gbarNa*(m1**3)*h1
    gNa2 = gbarNa*(m2**3)*h2
    gbarK = 0.36 #mS/cm2
    gK1 = gbarK*(n1**4)
    gK2 = gbarK*(n2**4)
    gbarL = 0.003 #mS/cm2
    gL = gbarL
    
    #Passing g1/g2 through vI might not be the best approach...
    gbars1 = vI_scn[3]
    gs1 = gbars1*s1
    gbars2 = vI_scn[4]
    gs2 = gbars2*s2
    
    #reversal potentials
    ENa = 55.17 #mV
    EK = -72.14 #mV
    EL = -49.42 #mV
    ES1 = 0 #ENa #mV #Excitatory Neuron (by this definition)
    ES2 = ES1
    #membrane capacitance
    Cm = 0.01 #uF/cm^2
        
    #NEURON1
    #Alpha and beta forms
    alpha_n1 = 0.01*(V1+50)/(1-np.exp(-(V1+50)/10))
    beta_n1 = 0.125*np.exp(-(V1+60)/80)
    alpha_m1 = 0.1*(V1+35)/(1-np.exp(-(V1+35)/10))
    beta_m1 = 4.0*np.exp(-0.0556*(V1+60))
    alpha_h1 = 0.07*np.exp(-0.05*(V1+60))
    beta_h1 = 1/(1+np.exp(-0.1*(V1+30)))
    #define each ODE                                        #NOTE: USE G OF S2 HERE, FOR EQN V1
    dV1dt = (1/Cm)*(gNa1*(ENa-V1) + gK1*(EK-V1) + gL*(EL-V1) + gs2*(ES2-V1) + I(t,vI_scn)) 
    dn1dt = alpha_n1*(1-n1)-beta_n1*n1
    dm1dt = alpha_m1*(1-m1)-beta_m1*m1
    dh1dt = alpha_h1*(1-h1)-beta_h1*h1
    
    #NEURON2
    #Alpha and beta forms
    alpha_n2 = 0.01*(V2+50)/(1-np.exp(-(V2+50)/10))
    beta_n2 = 0.125*np.exp(-(V2+60)/80)
    alpha_m2 = 0.1*(V2+35)/(1-np.exp(-(V2+35)/10))
    beta_m2 = 4.0*np.exp(-0.0556*(V2+60))
    alpha_h2 = 0.07*np.exp(-0.05*(V2+60))
    beta_h2 = 1/(1+np.exp(-0.1*(V2+30)))
    #define each ODE                                     #NOTE: USE G OF S1 HERE, FOR EQN V2
    dV2dt = (1/Cm)*(gNa2*(ENa-V2) + gK2*(EK-V2) + gL*(EL-V2) + gs1*(ES1-V2) + I(t,vI_scn)*0  )
    #^Set the applied current to neuron 2 to 0 so that only neuron 1 is spiking initially
    dn2dt = alpha_n2*(1-n2)-beta_n2*n2
    dm2dt = alpha_m2*(1-m2)-beta_m2*m2
    dh2dt = alpha_h2*(1-h2)-beta_h2*h2 
        
    ### FROM DR. RITT ###
    #s VARIABLE
    tau_s = 30 #10 #msec #--> Change made to extend the excitation period
    s_inf = 10.0/11.0  #arbitrary, just want it near 1
    alpha_s1 = (V1>0)*(1/tau_s) #(V1>0)*(10/tau_s) --> Ie change made to lower the rise time
    alpha_s2 = (V2>0)*(1/tau_s) #(V2>0)*(10/tau_s) --> Ie change made to lower the rise time
    beta_s = 1/tau_s
    ds1dt = alpha_s1*(1-s1)-beta_s*s1 
    ds2dt = alpha_s2*(1-s2)-beta_s*s2 
    
    return dV1dt, dn1dt, dm1dt, dh1dt, ds1dt, dV2dt, dn2dt, dm2dt, dh2dt, ds2dt

# %%
g1 = 0.2
g2 = g1
s1 = 0.006037
s2 = s1

tvec_start = 0
tvec_end_BURN = 50 #ms
tvec_end = 100
num_points = 5000
#Values to be passed in for generating an applied current:
t_start_CURRENT = 5 #ms
t_end_CURRENT = 7 #ms
amplitude_CURRENT = 0.1 #Amps (per cm^2?)

t = np.linspace(tvec_start,tvec_end_BURN,num_points) #ms
vI_scn_burn = [0,0,0,g1,g2]
#initial condition: V, n, m, h, s
V1 = -58; V2 = -58
n1 = 0.05; n2 = 0.05
m1 = 0.33; m2 = 0.33
h1 = 0.6; h2 = 0.6
x0_scn = [V1, n1, m1, h1, s1, V2, n2, m2, h2, s2]

#Burn in run
x_scn = odeint(odes_scn,x0_scn,t,args=(I,vI_scn_burn))
x_scn = np.transpose(x_scn)

t = np.linspace(tvec_start,tvec_end,num_points) #ms
vI_scn = [t_start_CURRENT,t_end_CURRENT,amplitude_CURRENT,g1,g2]
#initial condition: V, n, m, h, s 
V1 = x_scn[0,-1]
n1 = x_scn[1,-1]
m1 = x_scn[2,-1]
h1 = x_scn[3,-1]
s1 = x_scn[4,-1]

V2 = x_scn[5,-1]
n2 = x_scn[6,-1]
m2 = x_scn[7,-1]
h2 = x_scn[8,-1]
s2 = x_scn[9,-1]

x0_scn = [V1, n1, m1, h1, s1, V2, n2, m2, h2, s2]

x_scn = odeint(odes_scn,x0_scn,t,args=(I,vI_scn))
x_scn = np.transpose(x_scn)
plot_vnmh(x_scn,t)

# %%
#Procedurally verifying whether we can get periodic APs
found = 0
peak_threshold = 1 #mV #1 instead of 0 in order to provide an offset so it doesn't go crazy for small values of V1
AP_threshold = 30 #Requires that a range of 30 must be met in order to consider the differences in voltage an action potential

tvec_start = 0
tvec_end_BURN = 30 #ms
tvec_end = 40
num_points = 5000
halfway_point = int(np.floor(num_points/2))
#Values to be passed in for generating an applied current:
t_start_CURRENT = 5 #ms
t_end_CURRENT = 7 #ms
amplitude_CURRENT = 0.1 #Amps (per cm^2?)

t = np.linspace(tvec_start,tvec_end_BURN,num_points) #ms

#constants
s1 = 0.006037
s2 = s1
    
gMin = 0
gMax = 2
gPoints = 500

#Actual "function"
gRange = np.linspace(gMin,gMax,gPoints)
for gVal in gRange:
    g1 = gVal
    g2 = g1
    
    vI_scn = [t_start_CURRENT,t_end_CURRENT,amplitude_CURRENT,g1,g2]
    #initial condition: V, n, m, h, s
    V1 = -58; V2 = -58
    n1 = 0.05; n2 = 0.05
    m1 = 0.33; m2 = 0.33
    h1 = 0.6; h2 = 0.6
    x0_scn = [V1, n1, m1, h1, s1, V2, n2, m2, h2, s2]
    
    #Burn in run
    x_scn = odeint(odes_scn,x0_scn,t,args=(I,vI_scn))
    x_scn = np.transpose(x_scn)
    
    t = np.linspace(tvec_start,tvec_end,num_points) #ms
    vI_scn = [t_start_CURRENT,t_end_CURRENT,amplitude_CURRENT,g1,g2]
    #initial condition: V, n, m, h, s
    V1 = x_scn[0,-1] 
    n1 = x_scn[1,-1] 
    m1 = x_scn[2,-1] 
    h1 = x_scn[3,-1] 
    s1 = x_scn[4,-1] 
    V2 = x_scn[5,-1] 
    n2 = x_scn[6,-1] 
    m2 = x_scn[7,-1] 
    h2 = x_scn[8,-1] 
    s2 = x_scn[9,-1] 
    x0_scn = [V1, n1, m1, h1, s1, V2, n2, m2, h2, s2]
    
    #Actual run
    x_scn = odeint(odes_scn,x0_scn,t,args=(I,vI_scn))
    x_scn = np.transpose(x_scn)
    
    #Results
    V1_vec = x_scn[0,:]
    V2_vec = x_scn[5,:]
    diffV = np.subtract(V1_vec,V2_vec)
    arbThresh = 0.005
    if (diffV[0]<arbThresh and diffV[-1]<arbThresh):
        #Then V1 and V2 are the same
        pass
    else:
        print("V1 not equal to V2")
    
    V1_vec = V1_vec.tolist()
    max_val = max(V1_vec)
    min_val = min(V1_vec)
    max_idx = V1_vec.index(max_val)
    my_string = "Iter {my_iter:.0f}/{total}: max V1 for g of {temp_g:.5f} is {max_val:.3f}"
    print(my_string.format(my_iter = gVal/gMax*gPoints, total = gPoints, temp_g = gVal, max_val = max_val))
            
    #See if there a high value (ie above 0 since resting is about -60 mV) in the second half
    if max_idx<halfway_point: #ie does it occur in the first half
        for nextidx, nextV in enumerate(V1_vec[halfway_point:]):
            if (nextV>=peak_threshold) and (max_val-min_val>AP_threshold):
                print("Second spike found at index ", nextidx, "?")
                print("Found value is ", nextV)
                print("Max peak is ", max_val)
                vertIndex = (nextidx+halfway_point+1)/num_points*(tvec_end-tvec_start) #Adjust so that the index is now a time
                plot_vnmh(x_scn,t,vertIndex)
                print("--------------------------------")
                found = 1
                break
    if found:
        print("This should be the minimal g value for which spikes occur")
        break
    
    print("No 2nd peak found")
    print("--------------------------------")
    
if found==0:
    plot_vnmh(x_scn,t)
# Out:
# Iter 0/500: max V1 for g of 0.00000 is 45.165
# No 2nd peak found
# --------------------------------
# Iter 1/500: max V1 for g of 0.00401 is 45.138
# No 2nd peak found
# --------------------------------
# Iter 2/500: max V1 for g of 0.00802 is 45.145
# No 2nd peak found
# --------------------------------
# Iter 3/500: max V1 for g of 0.01202 is 45.149
# No 2nd peak found
# --------------------------------
# Iter 4/500: max V1 for g of 0.01603 is 45.151
# No 2nd peak found
# --------------------------------
# Iter 5/500: max V1 for g of 0.02004 is 45.152
# No 2nd peak found
# --------------------------------
# Iter 6/500: max V1 for g of 0.02405 is 45.152
# No 2nd peak found
# --------------------------------
# Iter 7/500: max V1 for g of 0.02806 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 8/500: max V1 for g of 0.03206 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 9/500: max V1 for g of 0.03607 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 10/500: max V1 for g of 0.04008 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 11/500: max V1 for g of 0.04409 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 12/500: max V1 for g of 0.04810 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 13/500: max V1 for g of 0.05210 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 14/500: max V1 for g of 0.05611 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 15/500: max V1 for g of 0.06012 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 16/500: max V1 for g of 0.06413 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 17/500: max V1 for g of 0.06814 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 18/500: max V1 for g of 0.07214 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 19/500: max V1 for g of 0.07615 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 20/500: max V1 for g of 0.08016 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 21/500: max V1 for g of 0.08417 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 22/500: max V1 for g of 0.08818 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 23/500: max V1 for g of 0.09218 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 24/500: max V1 for g of 0.09619 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 25/500: max V1 for g of 0.10020 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 26/500: max V1 for g of 0.10421 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 27/500: max V1 for g of 0.10822 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 28/500: max V1 for g of 0.11222 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 29/500: max V1 for g of 0.11623 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 30/500: max V1 for g of 0.12024 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 31/500: max V1 for g of 0.12425 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 32/500: max V1 for g of 0.12826 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 33/500: max V1 for g of 0.13226 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 34/500: max V1 for g of 0.13627 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 35/500: max V1 for g of 0.14028 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 36/500: max V1 for g of 0.14429 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 37/500: max V1 for g of 0.14830 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 38/500: max V1 for g of 0.15230 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 39/500: max V1 for g of 0.15631 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 40/500: max V1 for g of 0.16032 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 41/500: max V1 for g of 0.16433 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 42/500: max V1 for g of 0.16834 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 43/500: max V1 for g of 0.17234 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 44/500: max V1 for g of 0.17635 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 45/500: max V1 for g of 0.18036 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 46/500: max V1 for g of 0.18437 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 47/500: max V1 for g of 0.18838 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 48/500: max V1 for g of 0.19238 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 49/500: max V1 for g of 0.19639 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 50/500: max V1 for g of 0.20040 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 51/500: max V1 for g of 0.20441 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 52/500: max V1 for g of 0.20842 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 53/500: max V1 for g of 0.21242 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 54/500: max V1 for g of 0.21643 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 55/500: max V1 for g of 0.22044 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 56/500: max V1 for g of 0.22445 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 57/500: max V1 for g of 0.22846 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 58/500: max V1 for g of 0.23246 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 59/500: max V1 for g of 0.23647 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 60/500: max V1 for g of 0.24048 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 61/500: max V1 for g of 0.24449 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 62/500: max V1 for g of 0.24850 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 63/500: max V1 for g of 0.25251 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 64/500: max V1 for g of 0.25651 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 65/500: max V1 for g of 0.26052 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 66/500: max V1 for g of 0.26453 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 67/500: max V1 for g of 0.26854 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 68/500: max V1 for g of 0.27255 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 69/500: max V1 for g of 0.27655 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 70/500: max V1 for g of 0.28056 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 71/500: max V1 for g of 0.28457 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 72/500: max V1 for g of 0.28858 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 73/500: max V1 for g of 0.29259 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 74/500: max V1 for g of 0.29659 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 75/500: max V1 for g of 0.30060 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 76/500: max V1 for g of 0.30461 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 77/500: max V1 for g of 0.30862 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 78/500: max V1 for g of 0.31263 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 79/500: max V1 for g of 0.31663 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 80/500: max V1 for g of 0.32064 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 81/500: max V1 for g of 0.32465 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 82/500: max V1 for g of 0.32866 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 83/500: max V1 for g of 0.33267 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 84/500: max V1 for g of 0.33667 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 85/500: max V1 for g of 0.34068 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 86/500: max V1 for g of 0.34469 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 87/500: max V1 for g of 0.34870 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 88/500: max V1 for g of 0.35271 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 89/500: max V1 for g of 0.35671 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 90/500: max V1 for g of 0.36072 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 91/500: max V1 for g of 0.36473 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 92/500: max V1 for g of 0.36874 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 93/500: max V1 for g of 0.37275 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 94/500: max V1 for g of 0.37675 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 95/500: max V1 for g of 0.38076 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 96/500: max V1 for g of 0.38477 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 97/500: max V1 for g of 0.38878 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 98/500: max V1 for g of 0.39279 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 99/500: max V1 for g of 0.39679 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 100/500: max V1 for g of 0.40080 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 101/500: max V1 for g of 0.40481 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 102/500: max V1 for g of 0.40882 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 103/500: max V1 for g of 0.41283 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 104/500: max V1 for g of 0.41683 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 105/500: max V1 for g of 0.42084 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 106/500: max V1 for g of 0.42485 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 107/500: max V1 for g of 0.42886 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 108/500: max V1 for g of 0.43287 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 109/500: max V1 for g of 0.43687 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 110/500: max V1 for g of 0.44088 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 111/500: max V1 for g of 0.44489 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 112/500: max V1 for g of 0.44890 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 113/500: max V1 for g of 0.45291 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 114/500: max V1 for g of 0.45691 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 115/500: max V1 for g of 0.46092 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 116/500: max V1 for g of 0.46493 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 117/500: max V1 for g of 0.46894 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 118/500: max V1 for g of 0.47295 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 119/500: max V1 for g of 0.47695 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 120/500: max V1 for g of 0.48096 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 121/500: max V1 for g of 0.48497 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 122/500: max V1 for g of 0.48898 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 123/500: max V1 for g of 0.49299 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 124/500: max V1 for g of 0.49699 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 125/500: max V1 for g of 0.50100 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 126/500: max V1 for g of 0.50501 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 127/500: max V1 for g of 0.50902 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 128/500: max V1 for g of 0.51303 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 129/500: max V1 for g of 0.51703 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 130/500: max V1 for g of 0.52104 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 131/500: max V1 for g of 0.52505 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 132/500: max V1 for g of 0.52906 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 133/500: max V1 for g of 0.53307 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 134/500: max V1 for g of 0.53707 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 135/500: max V1 for g of 0.54108 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 136/500: max V1 for g of 0.54509 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 137/500: max V1 for g of 0.54910 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 138/500: max V1 for g of 0.55311 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 139/500: max V1 for g of 0.55711 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 140/500: max V1 for g of 0.56112 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 141/500: max V1 for g of 0.56513 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 142/500: max V1 for g of 0.56914 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 143/500: max V1 for g of 0.57315 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 144/500: max V1 for g of 0.57715 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 145/500: max V1 for g of 0.58116 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 146/500: max V1 for g of 0.58517 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 147/500: max V1 for g of 0.58918 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 148/500: max V1 for g of 0.59319 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 149/500: max V1 for g of 0.59719 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 150/500: max V1 for g of 0.60120 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 151/500: max V1 for g of 0.60521 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 152/500: max V1 for g of 0.60922 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 153/500: max V1 for g of 0.61323 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 154/500: max V1 for g of 0.61723 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 155/500: max V1 for g of 0.62124 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 156/500: max V1 for g of 0.62525 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 157/500: max V1 for g of 0.62926 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 158/500: max V1 for g of 0.63327 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 159/500: max V1 for g of 0.63727 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 160/500: max V1 for g of 0.64128 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 161/500: max V1 for g of 0.64529 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 162/500: max V1 for g of 0.64930 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 163/500: max V1 for g of 0.65331 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 164/500: max V1 for g of 0.65731 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 165/500: max V1 for g of 0.66132 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 166/500: max V1 for g of 0.66533 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 167/500: max V1 for g of 0.66934 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 168/500: max V1 for g of 0.67335 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 169/500: max V1 for g of 0.67735 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 170/500: max V1 for g of 0.68136 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 171/500: max V1 for g of 0.68537 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 172/500: max V1 for g of 0.68938 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 173/500: max V1 for g of 0.69339 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 174/500: max V1 for g of 0.69739 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 175/500: max V1 for g of 0.70140 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 176/500: max V1 for g of 0.70541 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 177/500: max V1 for g of 0.70942 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 178/500: max V1 for g of 0.71343 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 179/500: max V1 for g of 0.71743 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 180/500: max V1 for g of 0.72144 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 181/500: max V1 for g of 0.72545 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 182/500: max V1 for g of 0.72946 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 183/500: max V1 for g of 0.73347 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 184/500: max V1 for g of 0.73747 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 185/500: max V1 for g of 0.74148 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 186/500: max V1 for g of 0.74549 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 187/500: max V1 for g of 0.74950 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 188/500: max V1 for g of 0.75351 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 189/500: max V1 for g of 0.75752 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 190/500: max V1 for g of 0.76152 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 191/500: max V1 for g of 0.76553 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 192/500: max V1 for g of 0.76954 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 193/500: max V1 for g of 0.77355 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 194/500: max V1 for g of 0.77756 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 195/500: max V1 for g of 0.78156 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 196/500: max V1 for g of 0.78557 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 197/500: max V1 for g of 0.78958 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 198/500: max V1 for g of 0.79359 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 199/500: max V1 for g of 0.79760 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 200/500: max V1 for g of 0.80160 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 201/500: max V1 for g of 0.80561 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 202/500: max V1 for g of 0.80962 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 203/500: max V1 for g of 0.81363 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 204/500: max V1 for g of 0.81764 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 205/500: max V1 for g of 0.82164 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 206/500: max V1 for g of 0.82565 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 207/500: max V1 for g of 0.82966 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 208/500: max V1 for g of 0.83367 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 209/500: max V1 for g of 0.83768 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 210/500: max V1 for g of 0.84168 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 211/500: max V1 for g of 0.84569 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 212/500: max V1 for g of 0.84970 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 213/500: max V1 for g of 0.85371 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 214/500: max V1 for g of 0.85772 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 215/500: max V1 for g of 0.86172 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 216/500: max V1 for g of 0.86573 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 217/500: max V1 for g of 0.86974 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 218/500: max V1 for g of 0.87375 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 219/500: max V1 for g of 0.87776 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 220/500: max V1 for g of 0.88176 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 221/500: max V1 for g of 0.88577 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 222/500: max V1 for g of 0.88978 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 223/500: max V1 for g of 0.89379 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 224/500: max V1 for g of 0.89780 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 225/500: max V1 for g of 0.90180 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 226/500: max V1 for g of 0.90581 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 227/500: max V1 for g of 0.90982 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 228/500: max V1 for g of 0.91383 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 229/500: max V1 for g of 0.91784 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 230/500: max V1 for g of 0.92184 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 231/500: max V1 for g of 0.92585 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 232/500: max V1 for g of 0.92986 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 233/500: max V1 for g of 0.93387 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 234/500: max V1 for g of 0.93788 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 235/500: max V1 for g of 0.94188 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 236/500: max V1 for g of 0.94589 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 237/500: max V1 for g of 0.94990 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 238/500: max V1 for g of 0.95391 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 239/500: max V1 for g of 0.95792 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 240/500: max V1 for g of 0.96192 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 241/500: max V1 for g of 0.96593 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 242/500: max V1 for g of 0.96994 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 243/500: max V1 for g of 0.97395 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 244/500: max V1 for g of 0.97796 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 245/500: max V1 for g of 0.98196 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 246/500: max V1 for g of 0.98597 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 247/500: max V1 for g of 0.98998 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 248/500: max V1 for g of 0.99399 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 249/500: max V1 for g of 0.99800 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 251/500: max V1 for g of 1.00200 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 252/500: max V1 for g of 1.00601 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 253/500: max V1 for g of 1.01002 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 254/500: max V1 for g of 1.01403 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 255/500: max V1 for g of 1.01804 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 256/500: max V1 for g of 1.02204 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 257/500: max V1 for g of 1.02605 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 258/500: max V1 for g of 1.03006 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 259/500: max V1 for g of 1.03407 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 260/500: max V1 for g of 1.03808 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 261/500: max V1 for g of 1.04208 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 262/500: max V1 for g of 1.04609 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 263/500: max V1 for g of 1.05010 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 264/500: max V1 for g of 1.05411 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 265/500: max V1 for g of 1.05812 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 266/500: max V1 for g of 1.06212 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 267/500: max V1 for g of 1.06613 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 268/500: max V1 for g of 1.07014 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 269/500: max V1 for g of 1.07415 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 270/500: max V1 for g of 1.07816 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 271/500: max V1 for g of 1.08216 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 272/500: max V1 for g of 1.08617 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 273/500: max V1 for g of 1.09018 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 274/500: max V1 for g of 1.09419 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 275/500: max V1 for g of 1.09820 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 276/500: max V1 for g of 1.10220 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 277/500: max V1 for g of 1.10621 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 278/500: max V1 for g of 1.11022 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 279/500: max V1 for g of 1.11423 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 280/500: max V1 for g of 1.11824 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 281/500: max V1 for g of 1.12224 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 282/500: max V1 for g of 1.12625 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 283/500: max V1 for g of 1.13026 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 284/500: max V1 for g of 1.13427 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 285/500: max V1 for g of 1.13828 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 286/500: max V1 for g of 1.14228 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 287/500: max V1 for g of 1.14629 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 288/500: max V1 for g of 1.15030 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 289/500: max V1 for g of 1.15431 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 290/500: max V1 for g of 1.15832 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 291/500: max V1 for g of 1.16232 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 292/500: max V1 for g of 1.16633 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 293/500: max V1 for g of 1.17034 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 294/500: max V1 for g of 1.17435 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 295/500: max V1 for g of 1.17836 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 296/500: max V1 for g of 1.18236 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 297/500: max V1 for g of 1.18637 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 298/500: max V1 for g of 1.19038 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 299/500: max V1 for g of 1.19439 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 300/500: max V1 for g of 1.19840 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 301/500: max V1 for g of 1.20240 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 302/500: max V1 for g of 1.20641 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 303/500: max V1 for g of 1.21042 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 304/500: max V1 for g of 1.21443 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 305/500: max V1 for g of 1.21844 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 306/500: max V1 for g of 1.22244 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 307/500: max V1 for g of 1.22645 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 308/500: max V1 for g of 1.23046 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 309/500: max V1 for g of 1.23447 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 310/500: max V1 for g of 1.23848 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 311/500: max V1 for g of 1.24248 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 312/500: max V1 for g of 1.24649 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 313/500: max V1 for g of 1.25050 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 314/500: max V1 for g of 1.25451 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 315/500: max V1 for g of 1.25852 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 316/500: max V1 for g of 1.26253 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 317/500: max V1 for g of 1.26653 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 318/500: max V1 for g of 1.27054 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 319/500: max V1 for g of 1.27455 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 320/500: max V1 for g of 1.27856 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 321/500: max V1 for g of 1.28257 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 322/500: max V1 for g of 1.28657 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 323/500: max V1 for g of 1.29058 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 324/500: max V1 for g of 1.29459 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 325/500: max V1 for g of 1.29860 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 326/500: max V1 for g of 1.30261 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 327/500: max V1 for g of 1.30661 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 328/500: max V1 for g of 1.31062 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 329/500: max V1 for g of 1.31463 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 330/500: max V1 for g of 1.31864 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 331/500: max V1 for g of 1.32265 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 332/500: max V1 for g of 1.32665 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 333/500: max V1 for g of 1.33066 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 334/500: max V1 for g of 1.33467 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 335/500: max V1 for g of 1.33868 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 336/500: max V1 for g of 1.34269 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 337/500: max V1 for g of 1.34669 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 338/500: max V1 for g of 1.35070 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 339/500: max V1 for g of 1.35471 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 340/500: max V1 for g of 1.35872 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 341/500: max V1 for g of 1.36273 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 342/500: max V1 for g of 1.36673 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 343/500: max V1 for g of 1.37074 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 344/500: max V1 for g of 1.37475 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 345/500: max V1 for g of 1.37876 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 346/500: max V1 for g of 1.38277 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 347/500: max V1 for g of 1.38677 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 348/500: max V1 for g of 1.39078 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 349/500: max V1 for g of 1.39479 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 350/500: max V1 for g of 1.39880 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 351/500: max V1 for g of 1.40281 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 352/500: max V1 for g of 1.40681 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 353/500: max V1 for g of 1.41082 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 354/500: max V1 for g of 1.41483 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 355/500: max V1 for g of 1.41884 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 356/500: max V1 for g of 1.42285 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 357/500: max V1 for g of 1.42685 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 358/500: max V1 for g of 1.43086 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 359/500: max V1 for g of 1.43487 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 360/500: max V1 for g of 1.43888 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 361/500: max V1 for g of 1.44289 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 362/500: max V1 for g of 1.44689 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 363/500: max V1 for g of 1.45090 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 364/500: max V1 for g of 1.45491 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 365/500: max V1 for g of 1.45892 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 366/500: max V1 for g of 1.46293 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 367/500: max V1 for g of 1.46693 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 368/500: max V1 for g of 1.47094 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 369/500: max V1 for g of 1.47495 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 370/500: max V1 for g of 1.47896 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 371/500: max V1 for g of 1.48297 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 372/500: max V1 for g of 1.48697 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 373/500: max V1 for g of 1.49098 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 374/500: max V1 for g of 1.49499 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 375/500: max V1 for g of 1.49900 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 376/500: max V1 for g of 1.50301 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 377/500: max V1 for g of 1.50701 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 378/500: max V1 for g of 1.51102 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 379/500: max V1 for g of 1.51503 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 380/500: max V1 for g of 1.51904 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 381/500: max V1 for g of 1.52305 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 382/500: max V1 for g of 1.52705 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 383/500: max V1 for g of 1.53106 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 384/500: max V1 for g of 1.53507 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 385/500: max V1 for g of 1.53908 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 386/500: max V1 for g of 1.54309 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 387/500: max V1 for g of 1.54709 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 388/500: max V1 for g of 1.55110 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 389/500: max V1 for g of 1.55511 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 390/500: max V1 for g of 1.55912 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 391/500: max V1 for g of 1.56313 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 392/500: max V1 for g of 1.56713 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 393/500: max V1 for g of 1.57114 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 394/500: max V1 for g of 1.57515 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 395/500: max V1 for g of 1.57916 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 396/500: max V1 for g of 1.58317 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 397/500: max V1 for g of 1.58717 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 398/500: max V1 for g of 1.59118 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 399/500: max V1 for g of 1.59519 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 400/500: max V1 for g of 1.59920 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 401/500: max V1 for g of 1.60321 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 402/500: max V1 for g of 1.60721 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 403/500: max V1 for g of 1.61122 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 404/500: max V1 for g of 1.61523 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 405/500: max V1 for g of 1.61924 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 406/500: max V1 for g of 1.62325 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 407/500: max V1 for g of 1.62725 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 408/500: max V1 for g of 1.63126 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 409/500: max V1 for g of 1.63527 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 410/500: max V1 for g of 1.63928 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 411/500: max V1 for g of 1.64329 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 412/500: max V1 for g of 1.64729 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 413/500: max V1 for g of 1.65130 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 414/500: max V1 for g of 1.65531 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 415/500: max V1 for g of 1.65932 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 416/500: max V1 for g of 1.66333 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 417/500: max V1 for g of 1.66733 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 418/500: max V1 for g of 1.67134 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 419/500: max V1 for g of 1.67535 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 420/500: max V1 for g of 1.67936 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 421/500: max V1 for g of 1.68337 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 422/500: max V1 for g of 1.68737 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 423/500: max V1 for g of 1.69138 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 424/500: max V1 for g of 1.69539 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 425/500: max V1 for g of 1.69940 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 426/500: max V1 for g of 1.70341 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 427/500: max V1 for g of 1.70741 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 428/500: max V1 for g of 1.71142 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 429/500: max V1 for g of 1.71543 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 430/500: max V1 for g of 1.71944 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 431/500: max V1 for g of 1.72345 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 432/500: max V1 for g of 1.72745 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 433/500: max V1 for g of 1.73146 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 434/500: max V1 for g of 1.73547 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 435/500: max V1 for g of 1.73948 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 436/500: max V1 for g of 1.74349 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 437/500: max V1 for g of 1.74749 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 438/500: max V1 for g of 1.75150 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 439/500: max V1 for g of 1.75551 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 440/500: max V1 for g of 1.75952 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 441/500: max V1 for g of 1.76353 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 442/500: max V1 for g of 1.76754 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 443/500: max V1 for g of 1.77154 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 444/500: max V1 for g of 1.77555 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 445/500: max V1 for g of 1.77956 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 446/500: max V1 for g of 1.78357 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 447/500: max V1 for g of 1.78758 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 448/500: max V1 for g of 1.79158 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 449/500: max V1 for g of 1.79559 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 450/500: max V1 for g of 1.79960 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 451/500: max V1 for g of 1.80361 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 452/500: max V1 for g of 1.80762 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 453/500: max V1 for g of 1.81162 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 454/500: max V1 for g of 1.81563 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 455/500: max V1 for g of 1.81964 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 456/500: max V1 for g of 1.82365 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 457/500: max V1 for g of 1.82766 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 458/500: max V1 for g of 1.83166 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 459/500: max V1 for g of 1.83567 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 460/500: max V1 for g of 1.83968 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 461/500: max V1 for g of 1.84369 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 462/500: max V1 for g of 1.84770 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 463/500: max V1 for g of 1.85170 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 464/500: max V1 for g of 1.85571 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 465/500: max V1 for g of 1.85972 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 466/500: max V1 for g of 1.86373 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 467/500: max V1 for g of 1.86774 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 468/500: max V1 for g of 1.87174 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 469/500: max V1 for g of 1.87575 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 470/500: max V1 for g of 1.87976 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 471/500: max V1 for g of 1.88377 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 472/500: max V1 for g of 1.88778 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 473/500: max V1 for g of 1.89178 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 474/500: max V1 for g of 1.89579 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 475/500: max V1 for g of 1.89980 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 476/500: max V1 for g of 1.90381 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 477/500: max V1 for g of 1.90782 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 478/500: max V1 for g of 1.91182 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 479/500: max V1 for g of 1.91583 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 480/500: max V1 for g of 1.91984 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 481/500: max V1 for g of 1.92385 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 482/500: max V1 for g of 1.92786 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 483/500: max V1 for g of 1.93186 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 484/500: max V1 for g of 1.93587 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 485/500: max V1 for g of 1.93988 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 486/500: max V1 for g of 1.94389 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 487/500: max V1 for g of 1.94790 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 488/500: max V1 for g of 1.95190 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 489/500: max V1 for g of 1.95591 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 490/500: max V1 for g of 1.95992 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 491/500: max V1 for g of 1.96393 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 492/500: max V1 for g of 1.96794 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 493/500: max V1 for g of 1.97194 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 494/500: max V1 for g of 1.97595 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 495/500: max V1 for g of 1.97996 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 496/500: max V1 for g of 1.98397 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 497/500: max V1 for g of 1.98798 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 498/500: max V1 for g of 1.99198 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 499/500: max V1 for g of 1.99599 is 45.153
# No 2nd peak found
# --------------------------------
# Iter 500/500: max V1 for g of 2.00000 is 45.153
# No 2nd peak found
# --------------------------------

# %%
print(halfway_point)
print(V1_vec[halfway_point])
print(V1_vec[halfway_point+1])
print(V1_vec[halfway_point+10])
print(V1_vec[halfway_point+100])
print(V1_vec[halfway_point+400])
# Out:
# 2500
# -62.10008519111365
# -62.09360707735198
# -62.03566912912933
# -61.4927784834698
# -60.17246533175542
