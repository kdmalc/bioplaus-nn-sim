# %%
from scipy.integrate import odeint, solve_ivp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

COLOR = 'white'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR

# %% [markdown]
# # Week of 6/21
# Start embedding your model understanding into computational frameworks. So as an exercise, take a stab at implementing the Hodgkin Huxley model for numerical solution, e.g. using scipy (odeint or newer methods).
#
# ## Hodgkin-Huxley Model

# %%
def plot_vnmh(x,t,vertIndex=-1):
    '''
    Callable function for plotting V,n,m,h
    
    Params:
        x: Matrix, each column is one of the above variables
        t: Time vector for x axis
    '''
    
    #plot the results
    plt.figure(figsize=(15,10))
    #Font sizes
    title_font = 20
    label_font = 15

    #Trying to stop them overlapping:
    #fig, ax = plt.subplots(2,1) #--> fig overwrites so I am no longer working on the subplots
    #fig.tight_layout(h_pad=2)
    #fig.suptitle('Overall Title')
    
    #Extract variables from matrix
    if x.shape[1] == 4:
        V = x[:,0]
        n = x[:,1]
        m = x[:,2]
        h = x[:,3]
        
        plt.subplot(211)
        plt.title("Voltage as a Function of Time", fontsize=title_font, fontweight="bold")
        plt.ylabel("Volts (mV)", fontsize=label_font)
        plt.xlabel("Time (ms)", fontsize=label_font)
        plt.plot(t,V)
        
        plt.subplot(212)
        plt.title("Gating Variables as a Function of Time", fontsize=title_font, fontweight="bold")
        plt.ylabel("Volts (mV)", fontsize=label_font)
        plt.xlabel("Time (ms)", fontsize=label_font)
        plt.plot(t,n,label="n")
        plt.plot(t,m,label="m")
        plt.plot(t,h,label="h")
        leg = plt.legend(loc='upper right')
        for text in leg.get_texts():
            text.set_color('black')
        plt.show()
        
    elif x.shape[0] == 10:
        V1 = x[0]
        n1 = x[1]
        m1 = x[2]
        h1 = x[3]
        s1 = x[4]
        V2 = x[5]
        n2 = x[6]
        m2 = x[7]
        h2 = x[8]
        s2 = x[9]
            
        plt.subplot(211)
        plt.title("Voltage as a Function of Time", fontsize=title_font, fontweight="bold")
        plt.ylabel("Volts (mV)", fontsize=label_font)
        plt.xlabel("Time (ms)", fontsize=label_font)
        plt.plot(t,V1,label="Neuron 1")
        plt.plot(t,V2,label="Neuron 2")
        if (vertIndex < 0):
            pass
        else:
            plt.axvline(x = vertIndex, color = 'r', label = 'Index Above Threshold')
        leg = plt.legend(loc='upper right')
        for text in leg.get_texts():
            text.set_color('black')
        plt.show()
        
        plt.subplot(212)
        plt.title("Gating Variables as a Function of Time", fontsize=title_font, fontweight="bold")
        plt.ylabel("Volts (mV)", fontsize=label_font)
        plt.xlabel("Time (ms)", fontsize=label_font)
        plt.plot(t,n1,label="n1")
        plt.plot(t,m1,label="m1")
        plt.plot(t,h1,label="h1")
        plt.plot(t,n2,label="n2")
        plt.plot(t,m2,label="m2")
        plt.plot(t,h2,label="h2")
        leg = plt.legend(loc='upper right')
        for text in leg.get_texts():
            text.set_color('black')
        plt.show()

# %%
def odes(x0,t,I,vI):
    '''
    Defines the constants and differential equations for the base Hodgkin-Huxley equations
    
    Params:: 
        x0: ICs for V,n,m,h
        t: time vector, not sure if this is actually needed (not called in func)
        I: custom function, time varying current (square wave)
        vI: custom 3x1 vector for I function, just encapsulates the parameters needed for I to function
        
    Returns:: Differential equations of each variable as a vector
    '''
    
    #set ICs
    V = x0[0]
    n = x0[1]
    m = x0[2]
    h = x0[3]
    
    #Constants
    #Source: https://www.math.mcgill.ca/gantumur/docs/reps/RyanSicilianoHH.pdf
    #conductances (S is Siemens)
    gbarNa = 1.2 #mS/cm2
    gNa = gbarNa*(m**3)*h
    gbarK = 0.36 #mS/cm2
    gK = gbarK*(n**4)
    gbarL = 0.003 #mS/cm2
    gL = gbarL
    
    #reversal potentials
    ENa = 55.17 #mV
    EK = -72.14 #mV
    EL = -49.42 #mV
    #membrane capacitance
    Cm = 0.01 #uF/cm^2
    #Alpha and beta forms
    alpha_n = 0.01*(V+50)/(1-np.exp(-(V+50)/10))
    beta_n = 0.125*np.exp(-(V+60)/80)
    alpha_m = 0.1*(V+35)/(1-np.exp(-(V+35)/10))
    beta_m = 4.0*np.exp(-0.0556*(V+60))
    alpha_h = 0.07*np.exp(-0.05*(V+60))
    beta_h = 1/(1+np.exp(-0.1*(V+30)))

    #define each ODE
    dVdt = (1/Cm)*(gNa*(ENa-V) + gK*(EK-V) + gL*(EL-V) + I(t,vI))
    #dVdt = (gNa*(ENa-V) + gK*(EK-V) + gL*(EL-V) + I(t,vI))
    dndt = alpha_n*(1-n)-beta_n*n
    dmdt = alpha_m*(1-m)-beta_m*m
    dhdt = alpha_h*(1-h)-beta_h*h

    return dVdt, dndt, dmdt, dhdt

# %%
def I(t=0,vI=[0,0,0]):
    '''
    Determines the applied current, with respect to the HH model.  By default makes a square wave
    '''
    
    #Applied current
    t_start = vI[0]
    t_end = vI[1]
    amplitude = vI[2]
    
    applied_current = (t>=t_start)*(t<=t_end)*amplitude
    #Ie if t is within range [t_start,t_end], we apply some amount of current, amplitude
    #Recall: t>=C evaluates to a Boolean, which, when used numerically, is equivalent to 0 or 1
    return applied_current

# %% [markdown]
# BURN IN: instead of using the random, clean x0 initial conditions I found, we should use burn in to find what the true steady state of our system is.  I.e. let it run for a really long time and whatever it equilibriates to is what we will use for "true" SS going forward:

# %%
#initial condition: V, n, m, h
x0 = [-58, 0.05, 0.33, 0.6] #Found online... not sure if these are correct
#time vector
t = np.linspace(0,50,2000) #600
#vector needed 
vI = [0,0,0]

x = odeint(odes,x0,t,args=(I,vI))

V = x[:,0]
n = x[:,1]
m = x[:,2]
h = x[:,3]

plot_vnmh(x,t)

# %%
print("Comparing our original x0 to what our system of differntial equations seems to prefer as SS:")
print(x0)
x0_new = x[-1,:]
print(x0_new)
# Out:
# Comparing our original x0 to what our system of differntial equations seems to prefer as SS:
# [-58, 0.05, 0.33, 0.6]
# [-6.00470736e+01  3.16944630e-01  5.26385829e-02  5.97749949e-01]

# %%
#BURNED IN initial condition
#time vector
t = np.linspace(0,15,1000)
x = odeint(odes,x0_new,t,args=(I,vI))

V = x[:,0]
n = x[:,1]
m = x[:,2]
h = x[:,3]

plot_vnmh(x,t)

# %%
t = np.linspace(0,30,1000) #ms
#NOW SETTING vI to something realistic:
vI = [5,7,0.1]

x = odeint(odes,x0_new,t,args=(I,vI))

V = x[:,0]
n = x[:,1]
m = x[:,2]
h = x[:,3]

plot_vnmh(x,t)

# %% [markdown]
# ## Tasks Post 6/23 Meeting:
# 2. SYNAPTICALLY COUPLED NEURONS: Choose the reversal potential to be the same as the sodium current (Excitatory synapse)
# 3. Start with synpatic g of 0 to verify
# 4. Then begin increasing both g's --> numerically find some minimal set of g's, FIND SUSTAINED OSCILLATION OF CONTINUOUS SPIKING

# %%
def odes_scn(x0,t,I,vI_scn):
    '''
    Defines the constants and differential equations for the HH-compliant synaptically coupled neurons.
    
    Params:: 
        x0: ICs for V1,n1,m1,h1,s1,V2,n2,m2,h2,s2
        t: time vector, not sure if this is actually needed (not called in func)
        I: custom function, time varying current (square wave)
        vI_scn: custom 5x1 vector for I function, just encapsulates the parameters needed for I to function.  
          Also encapsulates the values for g1 and g2
        
    Returns:: Differential equations of each variable as a vector
    
    '''
        
    #set ICs
    V1 = x0[0]
    n1 = x0[1]
    m1 = x0[2]
    h1 = x0[3]
    s1 = x0[4]
    
    V2 = x0[5]
    n2 = x0[6]
    m2 = x0[7]
    h2 = x0[8]
    s2 = x0[9]
        
    #Constants
    #Source: https://www.math.mcgill.ca/gantumur/docs/reps/RyanSicilianoHH.pdf
    
    #conductances (S is Siemens)
    gbarNa = 1.2 #mS/cm2
    gNa1 = gbarNa*(m1**3)*h1
    gNa2 = gbarNa*(m2**3)*h2
    gbarK = 0.36 #mS/cm2
    gK1 = gbarK*(n1**4)
    gK2 = gbarK*(n2**4)
    gbarL = 0.003 #mS/cm2
    gL = gbarL
    
    #Passing g1/g2 through vI might not be the best approach...
    gbars1 = vI_scn[3]
    gs1 = gbars1*s1
    # ASSUMING S1 = S2, or for now, g1=g2
    gbars2 = vI_scn[4]
    gs2 = gbars2*s2
    
    #reversal potentials
    ENa = 55.17 #mV
    EK = -72.14 #mV
    EL = -49.42 #mV
    ES1 = ENa #mV #Excitatory Neuron (by this definition)
    ES2 = ES1
    #membrane capacitance
    Cm = 0.01 #uF/cm^2
        
    #NEURON1
    #Alpha and beta forms
    alpha_n1 = 0.01*(V1+50)/(1-np.exp(-(V1+50)/10))
    beta_n1 = 0.125*np.exp(-(V1+60)/80)
    alpha_m1 = 0.1*(V1+35)/(1-np.exp(-(V1+35)/10))
    beta_m1 = 4.0*np.exp(-0.0556*(V1+60))
    alpha_h1 = 0.07*np.exp(-0.05*(V1+60))
    beta_h1 = 1/(1+np.exp(-0.1*(V1+30)))
    #define each ODE                                        #NOTE: USE G OF S2 HERE, FOR EQN V1
    dV1dt = (1/Cm)*(gNa1*(ENa-V1) + gK1*(EK-V1) + gL*(EL-V1) + gs2*(ES2-V1) + I(t,vI_scn)) 
    dn1dt = alpha_n1*(1-n1)-beta_n1*n1
    dm1dt = alpha_m1*(1-m1)-beta_m1*m1
    dh1dt = alpha_h1*(1-h1)-beta_h1*h1
    
    #NEURON2
    #Alpha and beta forms
    alpha_n2 = 0.01*(V2+50)/(1-np.exp(-(V2+50)/10))
    beta_n2 = 0.125*np.exp(-(V2+60)/80)
    alpha_m2 = 0.1*(V2+35)/(1-np.exp(-(V2+35)/10))
    beta_m2 = 4.0*np.exp(-0.0556*(V2+60))
    alpha_h2 = 0.07*np.exp(-0.05*(V2+60))
    beta_h2 = 1/(1+np.exp(-0.1*(V2+30)))
    #define each ODE                                     #NOTE: USE G OF S1 HERE, FOR EQN V2
    dV2dt = (1/Cm)*(gNa2*(ENa-V2) + gK2*(EK-V2) + gL*(EL-V2) + gs1*(ES1-V2) + I(t,vI_scn))
    dn2dt = alpha_n2*(1-n2)-beta_n2*n2
    dm2dt = alpha_m2*(1-m2)-beta_m2*m2
    dh2dt = alpha_h2*(1-h2)-beta_h2*h2 
        
    ### FROM DR. RITT ###
    #s VARIABLE
    tau_s = 10  # msec
    s_inf = 10.0/11.0  #arbitrary, just want it near 1
    #Functionize these?
    alpha_s1 = (V1>0)*(10/tau_s)
    alpha_s2 = (V2>0)*(10/tau_s)
    beta_s = 1/tau_s
    #def alpha(V):
    #    return (V>0)*(10/tau_s)
    #def beta(V):
    #    return 1/tau_s
    ds1dt = alpha_s1*(1-s1)-beta_s*s1 
    ds2dt = alpha_s2*(1-s2)-beta_s*s2 
    
    return dV1dt, dn1dt, dm1dt, dh1dt, ds1dt, dV2dt, dn2dt, dm2dt, dh2dt, ds2dt

# %%
g1 = 0.33
g2 = g1
s1 = 0.006037
s2 = s1

tvec_start = 0
tvec_end_BURN = 50 #ms
tvec_end = 100
num_points = 5000
#Values to be passed in for generating an applied current:
t_start_CURRENT = 5 #ms
t_end_CURRENT = 7 #ms
amplitude_CURRENT = 0.1 #Amps (per cm^2?)

t = np.linspace(tvec_start,tvec_end_BURN,num_points) #ms
vI_scn = [t_start_CURRENT,t_end_CURRENT,amplitude_CURRENT,g1,g2]
#initial condition: V, n, m, h, s
V1 = -58; V2 = -58
n1 = 0.05; n2 = 0.05
m1 = 0.33; m2 = 0.33
h1 = 0.6; h2 = 0.6
#s1 = 0.5; s2 = 0.5
x0_scn = [V1, n1, m1, h1, s1, V2, n2, m2, h2, s2]

#Burn in run
x_scn = odeint(odes_scn,x0_scn,t,args=(I,vI_scn))
x_scn = np.transpose(x_scn)
#plot_vnmh(x_scn,t)

t = np.linspace(tvec_start,tvec_end,num_points) #ms
vI_scn = [t_start_CURRENT,t_end_CURRENT,amplitude_CURRENT,g1,g2]
#initial condition: V, n, m, h, s 
#Commented values are for g=0
V1 = x_scn[0,-1] #-6.00471422e+01
n1 = x_scn[1,-1] #3.16954741e-01
m1 = x_scn[2,-1] #5.26388943e-02
h1 = x_scn[3,-1] #5.97768455e-01
s1 = x_scn[4,-1] #-3.81327848e-11

V2 = x_scn[5,-1] #-6.00471422e+01 #Same as Neur1
n2 = x_scn[6,-1] #3.16954741e-01 #Same as Neur1
m2 = x_scn[7,-1] #5.26388943e-02 #Same as Neur1
h2 = x_scn[8,-1] #5.97768455e-01 #Same as Neur1
s2 = x_scn[9,-1] #-3.81327848e-11 #Same as Neur1

#print(x_scn[:,-1])

#s_initial, s_final
#1, 0.007440221187101991
#1.5, 0.00814638689804401
#0.5, 0.006734116199199403
#0.2, 0.006310429589380202
#0.8, 0.007157800263585501
#0.007, 0.006037885217584234
#0.006, 0.006036470657299054

x0_scn = [V1, n1, m1, h1, s1, V2, n2, m2, h2, s2]

x_scn = odeint(odes_scn,x0_scn,t,args=(I,vI_scn))
x_scn = np.transpose(x_scn)
plot_vnmh(x_scn,t)

# %%
#Procedurally verifying whether we can get periodic APs
found = 0
peak_threshold = 1 #mV #1 instead of 0 in order to provide an offset so it doesn't go crazy for small values of V1
AP_threshold = 30 #Requires that a range of 30 must be met in order to consider the differences in voltage an action potential

tvec_start = 0
tvec_end_BURN = 30 #ms
tvec_end = 40
num_points = 5000
halfway_point = int(np.floor(num_points/2))
#Values to be passed in for generating an applied current:
t_start_CURRENT = 5 #ms
t_end_CURRENT = 7 #ms
amplitude_CURRENT = 0.1 #Amps (per cm^2?)

t = np.linspace(tvec_start,tvec_end_BURN,num_points) #ms

#constants
s1 = 0.006037
s2 = s1
    
gMin = 0
gMax = 5
gPoints = 1000

#Actual "function"
gRange = np.linspace(gMin,gMax,gPoints)
for gVal in gRange:
    g1 = gVal
    g2 = g1
    
    vI_scn = [t_start_CURRENT,t_end_CURRENT,amplitude_CURRENT,g1,g2]
    #initial condition: V, n, m, h, s
    V1 = -58; V2 = -58
    n1 = 0.05; n2 = 0.05
    m1 = 0.33; m2 = 0.33
    h1 = 0.6; h2 = 0.6
    x0_scn = [V1, n1, m1, h1, s1, V2, n2, m2, h2, s2]
    
    #Burn in run
    x_scn = odeint(odes_scn,x0_scn,t,args=(I,vI_scn))
    x_scn = np.transpose(x_scn)
    
    t = np.linspace(tvec_start,tvec_end,num_points) #ms
    vI_scn = [t_start_CURRENT,t_end_CURRENT,amplitude_CURRENT,g1,g2]
    #initial condition: V, n, m, h, s
    V1 = x_scn[0,-1] 
    n1 = x_scn[1,-1] 
    m1 = x_scn[2,-1] 
    h1 = x_scn[3,-1] 
    s1 = x_scn[4,-1] 
    V2 = x_scn[5,-1] 
    n2 = x_scn[6,-1] 
    m2 = x_scn[7,-1] 
    h2 = x_scn[8,-1] 
    s2 = x_scn[9,-1] 
    x0_scn = [V1, n1, m1, h1, s1, V2, n2, m2, h2, s2]
    
    #Actual run
    x_scn = odeint(odes_scn,x0_scn,t,args=(I,vI_scn))
    x_scn = np.transpose(x_scn)
    
    #Results
    V1_vec = x_scn[0,:]
    V2_vec = x_scn[5,:]
    diffV = np.subtract(V1_vec,V2_vec)
    arbThresh = 0.005
    if (diffV[0]<arbThresh and diffV[-1]<arbThresh):
        #Then V1 and V2 are the same
        pass
    else:
        print("V1 not equal to V2")
    
    V1_vec = V1_vec.tolist()
    max_val = max(V1_vec)
    min_val = min(V1_vec)
    max_idx = V1_vec.index(max_val)
    my_string = "Iter {my_iter:.0f}/{total}: max V1 for g of {temp_g:.5f} is {max_val:.3f}"
    print(my_string.format(my_iter = gVal/gMax*gPoints, total = gPoints, temp_g = gVal, max_val = max_val))
            
    #See if there a high value (ie above 0 since resting is about -60 mV) in the second half
    if max_idx<halfway_point: #ie does it occur in the first half
        for nextidx, nextV in enumerate(V1_vec[halfway_point:]):
            if (nextV>=peak_threshold) and (max_val-min_val>AP_threshold):
                print("Second spike found at index ", nextidx, "?")
                print("Found value is ", nextV)
                print("Max peak is ", max_val)
                vertIndex = (nextidx+halfway_point+1)/num_points*(tvec_end-tvec_start) #Adjust so that the index is now a time
                plot_vnmh(x_scn,t,vertIndex)
                print("--------------------------------")
                found = 1
                break
    if found:
        print("This should be the minimal g value for which spikes occur")
        break
    
    print("No 2nd peak found")
    print("--------------------------------")
    
if found==0:
    plot_vnmh(x_scn,t)
# Out:
# Iter 0/1000: max V1 for g of 0.00000 is 45.165
# No 2nd peak found
# --------------------------------
# Iter 1/1000: max V1 for g of 0.00501 is 44.253
# No 2nd peak found
# --------------------------------
# Iter 2/1000: max V1 for g of 0.01001 is 43.447
# No 2nd peak found
# --------------------------------
# Iter 3/1000: max V1 for g of 0.01502 is 42.680
# No 2nd peak found
# --------------------------------
# Iter 4/1000: max V1 for g of 0.02002 is 41.951
# No 2nd peak found
# --------------------------------
# Iter 5/1000: max V1 for g of 0.02503 is 41.247
# No 2nd peak found
# --------------------------------
# Iter 6/1000: max V1 for g of 0.03003 is 40.567
# No 2nd peak found
# --------------------------------
# Iter 7/1000: max V1 for g of 0.03504 is 39.906
# No 2nd peak found
# --------------------------------
# Iter 8/1000: max V1 for g of 0.04004 is 39.263
# No 2nd peak found
# --------------------------------
# Iter 9/1000: max V1 for g of 0.04505 is 38.635
# No 2nd peak found
# --------------------------------
# Iter 10/1000: max V1 for g of 0.05005 is 38.019
# No 2nd peak found
# --------------------------------
# Iter 11/1000: max V1 for g of 0.05506 is 37.414
# No 2nd peak found
# --------------------------------
# Iter 12/1000: max V1 for g of 0.06006 is 36.819
# No 2nd peak found
# --------------------------------
# Iter 13/1000: max V1 for g of 0.06507 is 36.234
# No 2nd peak found
# --------------------------------
# Iter 14/1000: max V1 for g of 0.07007 is 35.662
# No 2nd peak found
# --------------------------------
# Iter 15/1000: max V1 for g of 0.07508 is 35.098
# No 2nd peak found
# --------------------------------
# Iter 16/1000: max V1 for g of 0.08008 is 34.542
# No 2nd peak found
# --------------------------------
# Iter 17/1000: max V1 for g of 0.08509 is 33.993
# No 2nd peak found
# --------------------------------
# Iter 18/1000: max V1 for g of 0.09009 is 33.451
# No 2nd peak found
# --------------------------------
# Iter 19/1000: max V1 for g of 0.09510 is 32.916
# No 2nd peak found
# --------------------------------
# Iter 20/1000: max V1 for g of 0.10010 is 32.386
# No 2nd peak found
# --------------------------------
# Iter 21/1000: max V1 for g of 0.10511 is 31.863
# No 2nd peak found
# --------------------------------
# Iter 22/1000: max V1 for g of 0.11011 is 31.344
# No 2nd peak found
# --------------------------------
# Iter 23/1000: max V1 for g of 0.11512 is 30.829
# No 2nd peak found
# --------------------------------
# Iter 24/1000: max V1 for g of 0.12012 is 30.323
# No 2nd peak found
# --------------------------------
# Iter 25/1000: max V1 for g of 0.12513 is 29.818
# No 2nd peak found
# --------------------------------
# Iter 26/1000: max V1 for g of 0.13013 is 29.316
# No 2nd peak found
# --------------------------------
# Iter 27/1000: max V1 for g of 0.13514 is 28.820
# No 2nd peak found
# --------------------------------
# Iter 28/1000: max V1 for g of 0.14014 is 28.324
# No 2nd peak found
# --------------------------------
# Iter 29/1000: max V1 for g of 0.14515 is 27.829
# No 2nd peak found
# --------------------------------
# Iter 30/1000: max V1 for g of 0.15015 is 27.340
# No 2nd peak found
# --------------------------------
# Iter 31/1000: max V1 for g of 0.15516 is 26.849
# No 2nd peak found
# --------------------------------
# Iter 32/1000: max V1 for g of 0.16016 is 26.358
# No 2nd peak found
# --------------------------------
# Iter 33/1000: max V1 for g of 0.16517 is 25.866
# No 2nd peak found
# --------------------------------
# Iter 34/1000: max V1 for g of 0.17017 is 25.374
# No 2nd peak found
# --------------------------------
# Iter 35/1000: max V1 for g of 0.17518 is 24.879
# No 2nd peak found
# --------------------------------
# Iter 36/1000: max V1 for g of 0.18018 is 24.381
# No 2nd peak found
# --------------------------------
# Iter 37/1000: max V1 for g of 0.18519 is 23.877
# No 2nd peak found
# --------------------------------
# Iter 38/1000: max V1 for g of 0.19019 is 23.367
# No 2nd peak found
# --------------------------------
# Iter 39/1000: max V1 for g of 0.19520 is 22.847
# No 2nd peak found
# --------------------------------
# Iter 40/1000: max V1 for g of 0.20020 is 22.320
# No 2nd peak found
# --------------------------------
# Iter 41/1000: max V1 for g of 0.20521 is 21.778
# No 2nd peak found
# --------------------------------
# Iter 42/1000: max V1 for g of 0.21021 is 21.219
# No 2nd peak found
# --------------------------------
# Iter 43/1000: max V1 for g of 0.21522 is 20.642
# No 2nd peak found
# --------------------------------
# Iter 44/1000: max V1 for g of 0.22022 is 20.037
# No 2nd peak found
# --------------------------------
# Iter 45/1000: max V1 for g of 0.22523 is 19.402
# No 2nd peak found
# --------------------------------
# Iter 46/1000: max V1 for g of 0.23023 is 18.725
# No 2nd peak found
# --------------------------------
# Iter 47/1000: max V1 for g of 0.23524 is 17.990
# No 2nd peak found
# --------------------------------
# Iter 48/1000: max V1 for g of 0.24024 is 17.177
# No 2nd peak found
# --------------------------------
# Iter 49/1000: max V1 for g of 0.24525 is 16.248
# No 2nd peak found
# --------------------------------
# Iter 50/1000: max V1 for g of 0.25025 is 15.129
# No 2nd peak found
# --------------------------------
# Iter 51/1000: max V1 for g of 0.25526 is 13.621
# No 2nd peak found
# --------------------------------
# Iter 52/1000: max V1 for g of 0.26026 is -0.270
# No 2nd peak found
# --------------------------------
# Iter 53/1000: max V1 for g of 0.26527 is -2.230
# No 2nd peak found
# --------------------------------
# Iter 54/1000: max V1 for g of 0.27027 is -4.690
# No 2nd peak found
# --------------------------------
# Iter 55/1000: max V1 for g of 0.27528 is -8.330
# No 2nd peak found
# --------------------------------
# Iter 56/1000: max V1 for g of 0.28028 is -19.754
# No 2nd peak found
# --------------------------------
# Iter 57/1000: max V1 for g of 0.28529 is -41.599
# No 2nd peak found
# --------------------------------
# Iter 58/1000: max V1 for g of 0.29029 is -42.040
# No 2nd peak found
# --------------------------------
# Iter 59/1000: max V1 for g of 0.29530 is -42.202
# No 2nd peak found
# --------------------------------
# Iter 60/1000: max V1 for g of 0.30030 is -42.360
# No 2nd peak found
# --------------------------------
# Iter 61/1000: max V1 for g of 0.30531 is -42.516
# No 2nd peak found
# --------------------------------
# Iter 62/1000: max V1 for g of 0.31031 is -42.671
# No 2nd peak found
# --------------------------------
# Iter 63/1000: max V1 for g of 0.31532 is -42.891
# No 2nd peak found
# --------------------------------
# Iter 64/1000: max V1 for g of 0.32032 is -43.056
# No 2nd peak found
# --------------------------------
# Iter 65/1000: max V1 for g of 0.32533 is -43.233
# No 2nd peak found
# --------------------------------
# Iter 66/1000: max V1 for g of 0.33033 is -43.186
# No 2nd peak found
# --------------------------------
# Iter 67/1000: max V1 for g of 0.33534 is 0.284
# No 2nd peak found
# --------------------------------
# Iter 68/1000: max V1 for g of 0.34034 is 0.604
# No 2nd peak found
# --------------------------------
# Iter 69/1000: max V1 for g of 0.34535 is 0.921
# No 2nd peak found
# --------------------------------
# Iter 70/1000: max V1 for g of 0.35035 is 1.234
# No 2nd peak found
# --------------------------------
# Iter 71/1000: max V1 for g of 0.35536 is 1.544
# No 2nd peak found
# --------------------------------
# Iter 72/1000: max V1 for g of 0.36036 is 1.850
# No 2nd peak found
# --------------------------------
# Iter 73/1000: max V1 for g of 0.36537 is 2.152
# No 2nd peak found
# --------------------------------
# Iter 74/1000: max V1 for g of 0.37037 is 2.451
# No 2nd peak found
# --------------------------------
# Iter 75/1000: max V1 for g of 0.37538 is 2.747
# No 2nd peak found
# --------------------------------
# Iter 76/1000: max V1 for g of 0.38038 is 3.040
# No 2nd peak found
# --------------------------------
# Iter 77/1000: max V1 for g of 0.38539 is 3.329
# No 2nd peak found
# --------------------------------
# Iter 78/1000: max V1 for g of 0.39039 is 3.616
# No 2nd peak found
# --------------------------------
# Iter 79/1000: max V1 for g of 0.39540 is 3.899
# No 2nd peak found
# --------------------------------
# Iter 80/1000: max V1 for g of 0.40040 is 4.179
# No 2nd peak found
# --------------------------------
# Iter 81/1000: max V1 for g of 0.40541 is 4.456
# No 2nd peak found
# --------------------------------
# Iter 82/1000: max V1 for g of 0.41041 is 4.730
# No 2nd peak found
# --------------------------------
# Iter 83/1000: max V1 for g of 0.41542 is 5.002
# No 2nd peak found
# --------------------------------
# Iter 84/1000: max V1 for g of 0.42042 is 5.270
# No 2nd peak found
# --------------------------------
# Iter 85/1000: max V1 for g of 0.42543 is 5.536
# No 2nd peak found
# --------------------------------
# Iter 86/1000: max V1 for g of 0.43043 is 5.799
# No 2nd peak found
# --------------------------------
# Iter 87/1000: max V1 for g of 0.43544 is 6.059
# No 2nd peak found
# --------------------------------
# Iter 88/1000: max V1 for g of 0.44044 is 6.316
# No 2nd peak found
# --------------------------------
# Iter 89/1000: max V1 for g of 0.44545 is 6.571
# No 2nd peak found
# --------------------------------
# Iter 90/1000: max V1 for g of 0.45045 is 6.824
# No 2nd peak found
# --------------------------------
# Iter 91/1000: max V1 for g of 0.45546 is 7.073
# No 2nd peak found
# --------------------------------
# Iter 92/1000: max V1 for g of 0.46046 is 7.320
# No 2nd peak found
# --------------------------------
# Iter 93/1000: max V1 for g of 0.46547 is 7.565
# No 2nd peak found
# --------------------------------
# Iter 94/1000: max V1 for g of 0.47047 is 7.807
# No 2nd peak found
# --------------------------------
# Iter 95/1000: max V1 for g of 0.47548 is 8.047
# No 2nd peak found
# --------------------------------
# Iter 96/1000: max V1 for g of 0.48048 is 8.285
# No 2nd peak found
# --------------------------------
# Iter 97/1000: max V1 for g of 0.48549 is 8.520
# No 2nd peak found
# --------------------------------
# Iter 98/1000: max V1 for g of 0.49049 is 8.753
# No 2nd peak found
# --------------------------------
# Iter 99/1000: max V1 for g of 0.49550 is 8.984
# No 2nd peak found
# --------------------------------
# Iter 100/1000: max V1 for g of 0.50050 is 9.212
# No 2nd peak found
# --------------------------------
# Iter 101/1000: max V1 for g of 0.50551 is 9.438
# No 2nd peak found
# --------------------------------
# Iter 102/1000: max V1 for g of 0.51051 is 9.662
# No 2nd peak found
# --------------------------------
# Iter 103/1000: max V1 for g of 0.51552 is 9.884
# No 2nd peak found
# --------------------------------
# Iter 104/1000: max V1 for g of 0.52052 is 10.104
# No 2nd peak found
# --------------------------------
# Iter 105/1000: max V1 for g of 0.52553 is 10.321
# No 2nd peak found
# --------------------------------
# Iter 106/1000: max V1 for g of 0.53053 is 10.669
# No 2nd peak found
# --------------------------------
# Iter 107/1000: max V1 for g of 0.53554 is 10.882
# No 2nd peak found
# --------------------------------
# Iter 108/1000: max V1 for g of 0.54054 is 10.962
# No 2nd peak found
# --------------------------------
# Iter 109/1000: max V1 for g of 0.54555 is 11.172
# No 2nd peak found
# --------------------------------
# Iter 110/1000: max V1 for g of 0.55055 is 11.379
# No 2nd peak found
# --------------------------------
# Iter 111/1000: max V1 for g of 0.55556 is 11.585
# No 2nd peak found
# --------------------------------
# Iter 112/1000: max V1 for g of 0.56056 is 11.789
# No 2nd peak found
# --------------------------------
# Iter 113/1000: max V1 for g of 0.56557 is 11.991
# No 2nd peak found
# --------------------------------
# Iter 114/1000: max V1 for g of 0.57057 is 12.191
# No 2nd peak found
# --------------------------------
# Iter 115/1000: max V1 for g of 0.57558 is 12.390
# No 2nd peak found
# --------------------------------
# Iter 116/1000: max V1 for g of 0.58058 is 12.586
# No 2nd peak found
# --------------------------------
# Iter 117/1000: max V1 for g of 0.58559 is 12.781
# No 2nd peak found
# --------------------------------
# Iter 118/1000: max V1 for g of 0.59059 is 12.974
# No 2nd peak found
# --------------------------------
# Iter 119/1000: max V1 for g of 0.59560 is 13.287
# No 2nd peak found
# --------------------------------
# Iter 120/1000: max V1 for g of 0.60060 is 13.355
# No 2nd peak found
# --------------------------------
# Iter 121/1000: max V1 for g of 0.60561 is 13.543
# No 2nd peak found
# --------------------------------
# Iter 122/1000: max V1 for g of 0.61061 is 13.729
# No 2nd peak found
# --------------------------------
# Iter 123/1000: max V1 for g of 0.61562 is 13.914
# No 2nd peak found
# --------------------------------
# Iter 124/1000: max V1 for g of 0.62062 is 14.097
# No 2nd peak found
# --------------------------------
# Iter 125/1000: max V1 for g of 0.62563 is 14.279
# No 2nd peak found
# --------------------------------
# Iter 126/1000: max V1 for g of 0.63063 is 14.459
# No 2nd peak found
# --------------------------------
# Iter 127/1000: max V1 for g of 0.63564 is 14.637
# No 2nd peak found
# --------------------------------
# Iter 128/1000: max V1 for g of 0.64064 is 14.814
# No 2nd peak found
# --------------------------------
# Iter 129/1000: max V1 for g of 0.64565 is 14.989
# No 2nd peak found
# --------------------------------
# Iter 130/1000: max V1 for g of 0.65065 is 15.163
# No 2nd peak found
# --------------------------------
# Iter 131/1000: max V1 for g of 0.65566 is 15.335
# No 2nd peak found
# --------------------------------
# Iter 132/1000: max V1 for g of 0.66066 is 15.506
# No 2nd peak found
# --------------------------------
# Iter 133/1000: max V1 for g of 0.66567 is 15.676
# No 2nd peak found
# --------------------------------
# Iter 134/1000: max V1 for g of 0.67067 is 15.844
# No 2nd peak found
# --------------------------------
# Iter 135/1000: max V1 for g of 0.67568 is 16.011
# No 2nd peak found
# --------------------------------
# Iter 136/1000: max V1 for g of 0.68068 is 16.176
# No 2nd peak found
# --------------------------------
# Iter 137/1000: max V1 for g of 0.68569 is 16.450
# No 2nd peak found
# --------------------------------
# Iter 138/1000: max V1 for g of 0.69069 is 16.502
# No 2nd peak found
# --------------------------------
# Iter 139/1000: max V1 for g of 0.69570 is 16.664
# No 2nd peak found
# --------------------------------
# Iter 140/1000: max V1 for g of 0.70070 is 16.824
# No 2nd peak found
# --------------------------------
# Iter 141/1000: max V1 for g of 0.70571 is 16.982
# No 2nd peak found
# --------------------------------
# Iter 142/1000: max V1 for g of 0.71071 is 17.247
# No 2nd peak found
# --------------------------------
# Iter 143/1000: max V1 for g of 0.71572 is 17.296
# No 2nd peak found
# --------------------------------
# Iter 144/1000: max V1 for g of 0.72072 is 17.450
# No 2nd peak found
# --------------------------------
# Iter 145/1000: max V1 for g of 0.72573 is 17.604
# No 2nd peak found
# --------------------------------
# Iter 146/1000: max V1 for g of 0.73073 is 17.756
# No 2nd peak found
# --------------------------------
# Iter 147/1000: max V1 for g of 0.73574 is 17.907
# No 2nd peak found
# --------------------------------
# Iter 148/1000: max V1 for g of 0.74074 is 18.057
# No 2nd peak found
# --------------------------------
# Iter 149/1000: max V1 for g of 0.74575 is 18.206
# No 2nd peak found
# --------------------------------
# Iter 150/1000: max V1 for g of 0.75075 is 18.354
# No 2nd peak found
# --------------------------------
# Iter 151/1000: max V1 for g of 0.75576 is 18.500
# No 2nd peak found
# --------------------------------
# Iter 152/1000: max V1 for g of 0.76076 is 18.645
# No 2nd peak found
# --------------------------------
# Iter 153/1000: max V1 for g of 0.76577 is 18.790
# No 2nd peak found
# --------------------------------
# Iter 154/1000: max V1 for g of 0.77077 is 18.933
# No 2nd peak found
# --------------------------------
# Iter 155/1000: max V1 for g of 0.77578 is 19.075
# No 2nd peak found
# --------------------------------
# Iter 156/1000: max V1 for g of 0.78078 is 19.215
# No 2nd peak found
# --------------------------------
# Iter 157/1000: max V1 for g of 0.78579 is 19.355
# No 2nd peak found
# --------------------------------
# Iter 158/1000: max V1 for g of 0.79079 is 19.494
# No 2nd peak found
# --------------------------------
# Iter 159/1000: max V1 for g of 0.79580 is 19.632
# No 2nd peak found
# --------------------------------
# Iter 160/1000: max V1 for g of 0.80080 is 19.768
# No 2nd peak found
# --------------------------------
# Iter 161/1000: max V1 for g of 0.80581 is 19.904
# No 2nd peak found
# --------------------------------
# Iter 162/1000: max V1 for g of 0.81081 is 20.038
# No 2nd peak found
# --------------------------------
# Iter 163/1000: max V1 for g of 0.81582 is 20.172
# No 2nd peak found
# --------------------------------
# Iter 164/1000: max V1 for g of 0.82082 is 20.304
# No 2nd peak found
# --------------------------------
# Iter 165/1000: max V1 for g of 0.82583 is 20.436
# No 2nd peak found
# --------------------------------
# Iter 166/1000: max V1 for g of 0.83083 is 20.567
# No 2nd peak found
# --------------------------------
# Iter 167/1000: max V1 for g of 0.83584 is 20.696
# No 2nd peak found
# --------------------------------
# Iter 168/1000: max V1 for g of 0.84084 is 20.825
# No 2nd peak found
# --------------------------------
# Iter 169/1000: max V1 for g of 0.84585 is 20.953
# No 2nd peak found
# --------------------------------
# Iter 170/1000: max V1 for g of 0.85085 is 21.079
# No 2nd peak found
# --------------------------------
# Iter 171/1000: max V1 for g of 0.85586 is 21.205
# No 2nd peak found
# --------------------------------
# Iter 172/1000: max V1 for g of 0.86086 is 21.330
# No 2nd peak found
# --------------------------------
# Iter 173/1000: max V1 for g of 0.86587 is 21.454
# No 2nd peak found
# --------------------------------
# Iter 174/1000: max V1 for g of 0.87087 is 21.577
# No 2nd peak found
# --------------------------------
# Iter 175/1000: max V1 for g of 0.87588 is 21.700
# No 2nd peak found
# --------------------------------
# Iter 176/1000: max V1 for g of 0.88088 is 21.821
# No 2nd peak found
# --------------------------------
# Iter 177/1000: max V1 for g of 0.88589 is 21.942
# No 2nd peak found
# --------------------------------
# Iter 178/1000: max V1 for g of 0.89089 is 22.061
# No 2nd peak found
# --------------------------------
# Iter 179/1000: max V1 for g of 0.89590 is 22.180
# No 2nd peak found
# --------------------------------
# Iter 180/1000: max V1 for g of 0.90090 is 22.298
# No 2nd peak found
# --------------------------------
# Iter 181/1000: max V1 for g of 0.90591 is 22.415
# No 2nd peak found
# --------------------------------
# Iter 182/1000: max V1 for g of 0.91091 is 22.531
# No 2nd peak found
# --------------------------------
# Iter 183/1000: max V1 for g of 0.91592 is 22.647
# No 2nd peak found
# --------------------------------
# Iter 184/1000: max V1 for g of 0.92092 is 22.762
# No 2nd peak found
# --------------------------------
# Iter 185/1000: max V1 for g of 0.92593 is 22.876
# No 2nd peak found
# --------------------------------
# Iter 186/1000: max V1 for g of 0.93093 is 22.989
# No 2nd peak found
# --------------------------------
# Iter 187/1000: max V1 for g of 0.93594 is 23.101
# No 2nd peak found
# --------------------------------
# Iter 188/1000: max V1 for g of 0.94094 is 23.213
# No 2nd peak found
# --------------------------------
# Iter 189/1000: max V1 for g of 0.94595 is 23.323
# No 2nd peak found
# --------------------------------
# Iter 190/1000: max V1 for g of 0.95095 is 23.434
# No 2nd peak found
# --------------------------------
# Iter 191/1000: max V1 for g of 0.95596 is 23.543
# No 2nd peak found
# --------------------------------
# Iter 192/1000: max V1 for g of 0.96096 is 23.651
# No 2nd peak found
# --------------------------------
# Iter 193/1000: max V1 for g of 0.96597 is 23.759
# No 2nd peak found
# --------------------------------
# Iter 194/1000: max V1 for g of 0.97097 is 23.866
# No 2nd peak found
# --------------------------------
# Iter 195/1000: max V1 for g of 0.97598 is 23.973
# No 2nd peak found
# --------------------------------
# Iter 196/1000: max V1 for g of 0.98098 is 24.078
# No 2nd peak found
# --------------------------------
# Iter 197/1000: max V1 for g of 0.98599 is 24.183
# No 2nd peak found
# --------------------------------
# Iter 198/1000: max V1 for g of 0.99099 is 24.288
# No 2nd peak found
# --------------------------------
# Iter 199/1000: max V1 for g of 0.99600 is 24.391
# No 2nd peak found
# --------------------------------
# Iter 200/1000: max V1 for g of 1.00100 is 24.494
# No 2nd peak found
# --------------------------------
# Iter 201/1000: max V1 for g of 1.00601 is 24.596
# No 2nd peak found
# --------------------------------
# Iter 202/1000: max V1 for g of 1.01101 is 24.698
# No 2nd peak found
# --------------------------------
# Iter 203/1000: max V1 for g of 1.01602 is 24.799
# No 2nd peak found
# --------------------------------
# Iter 204/1000: max V1 for g of 1.02102 is 24.899
# No 2nd peak found
# --------------------------------
# Iter 205/1000: max V1 for g of 1.02603 is 25.080
# No 2nd peak found
# --------------------------------
# Iter 206/1000: max V1 for g of 1.03103 is 25.097
# No 2nd peak found
# --------------------------------
# Iter 207/1000: max V1 for g of 1.03604 is 25.196
# No 2nd peak found
# --------------------------------
# Iter 208/1000: max V1 for g of 1.04104 is 25.293
# No 2nd peak found
# --------------------------------
# Iter 209/1000: max V1 for g of 1.04605 is 25.390
# No 2nd peak found
# --------------------------------
# Iter 210/1000: max V1 for g of 1.05105 is 25.566
# No 2nd peak found
# --------------------------------
# Iter 211/1000: max V1 for g of 1.05606 is 25.582
# No 2nd peak found
# --------------------------------
# Iter 212/1000: max V1 for g of 1.06106 is 25.678
# No 2nd peak found
# --------------------------------
# Iter 213/1000: max V1 for g of 1.06607 is 25.772
# No 2nd peak found
# --------------------------------
# Iter 214/1000: max V1 for g of 1.07107 is 25.866
# No 2nd peak found
# --------------------------------
# Iter 215/1000: max V1 for g of 1.07608 is 26.038
# No 2nd peak found
# --------------------------------
# Iter 216/1000: max V1 for g of 1.08108 is 26.052
# No 2nd peak found
# --------------------------------
# Iter 217/1000: max V1 for g of 1.08609 is 26.144
# No 2nd peak found
# --------------------------------
# Iter 218/1000: max V1 for g of 1.09109 is 26.314
# No 2nd peak found
# --------------------------------
# Iter 219/1000: max V1 for g of 1.09610 is 26.327
# No 2nd peak found
# --------------------------------
# Iter 220/1000: max V1 for g of 1.10110 is 26.494
# No 2nd peak found
# --------------------------------
# Iter 221/1000: max V1 for g of 1.10611 is 26.584
# No 2nd peak found
# --------------------------------
# Iter 222/1000: max V1 for g of 1.11111 is 26.673
# No 2nd peak found
# --------------------------------
# Iter 223/1000: max V1 for g of 1.11612 is 26.686
# No 2nd peak found
# --------------------------------
# Iter 224/1000: max V1 for g of 1.12112 is 26.774
# No 2nd peak found
# --------------------------------
# Iter 225/1000: max V1 for g of 1.12613 is 26.862
# No 2nd peak found
# --------------------------------
# Iter 226/1000: max V1 for g of 1.13113 is 27.024
# No 2nd peak found
# --------------------------------
# Iter 227/1000: max V1 for g of 1.13614 is 27.036
# No 2nd peak found
# --------------------------------
# Iter 228/1000: max V1 for g of 1.14114 is 27.122
# No 2nd peak found
# --------------------------------
# Iter 229/1000: max V1 for g of 1.14615 is 27.207
# No 2nd peak found
# --------------------------------
# Iter 230/1000: max V1 for g of 1.15115 is 27.293
# No 2nd peak found
# --------------------------------
# Iter 231/1000: max V1 for g of 1.15616 is 27.451
# No 2nd peak found
# --------------------------------
# Iter 232/1000: max V1 for g of 1.16116 is 27.535
# No 2nd peak found
# --------------------------------
# Iter 233/1000: max V1 for g of 1.16617 is 27.545
# No 2nd peak found
# --------------------------------
# Iter 234/1000: max V1 for g of 1.17117 is 27.628
# No 2nd peak found
# --------------------------------
# Iter 235/1000: max V1 for g of 1.17618 is 27.710
# No 2nd peak found
# --------------------------------
# Iter 236/1000: max V1 for g of 1.18118 is 27.793
# No 2nd peak found
# --------------------------------
# Iter 237/1000: max V1 for g of 1.18619 is 27.874
# No 2nd peak found
# --------------------------------
# Iter 238/1000: max V1 for g of 1.19119 is 28.027
# No 2nd peak found
# --------------------------------
# Iter 239/1000: max V1 for g of 1.19620 is 28.108
# No 2nd peak found
# --------------------------------
# Iter 240/1000: max V1 for g of 1.20120 is 28.116
# No 2nd peak found
# --------------------------------
# Iter 241/1000: max V1 for g of 1.20621 is 28.267
# No 2nd peak found
# --------------------------------
# Iter 242/1000: max V1 for g of 1.21121 is 28.346
# No 2nd peak found
# --------------------------------
# Iter 243/1000: max V1 for g of 1.21622 is 28.425
# No 2nd peak found
# --------------------------------
# Iter 244/1000: max V1 for g of 1.22122 is 28.432
# No 2nd peak found
# --------------------------------
# Iter 245/1000: max V1 for g of 1.22623 is 28.510
# No 2nd peak found
# --------------------------------
# Iter 246/1000: max V1 for g of 1.23123 is 28.658
# No 2nd peak found
# --------------------------------
# Iter 247/1000: max V1 for g of 1.23624 is 28.665
# No 2nd peak found
# --------------------------------
# Iter 248/1000: max V1 for g of 1.24124 is 28.741
# No 2nd peak found
# --------------------------------
# Iter 249/1000: max V1 for g of 1.24625 is 28.887
# No 2nd peak found
# --------------------------------
# Iter 250/1000: max V1 for g of 1.25125 is 28.893
# No 2nd peak found
# --------------------------------
# Iter 251/1000: max V1 for g of 1.25626 is 29.037
# No 2nd peak found
# --------------------------------
# Iter 252/1000: max V1 for g of 1.26126 is 29.043
# No 2nd peak found
# --------------------------------
# Iter 253/1000: max V1 for g of 1.26627 is 29.186
# No 2nd peak found
# --------------------------------
# Iter 254/1000: max V1 for g of 1.27127 is 29.191
# No 2nd peak found
# --------------------------------
# Iter 255/1000: max V1 for g of 1.27628 is 29.265
# No 2nd peak found
# --------------------------------
# Iter 256/1000: max V1 for g of 1.28128 is 29.338
# No 2nd peak found
# --------------------------------
# Iter 257/1000: max V1 for g of 1.28629 is 29.411
# No 2nd peak found
# --------------------------------
# Iter 258/1000: max V1 for g of 1.29129 is 29.483
# No 2nd peak found
# --------------------------------
# Iter 259/1000: max V1 for g of 1.29630 is 29.555
# No 2nd peak found
# --------------------------------
# Iter 260/1000: max V1 for g of 1.30130 is 29.694
# No 2nd peak found
# --------------------------------
# Iter 261/1000: max V1 for g of 1.30631 is 29.765
# No 2nd peak found
# --------------------------------
# Iter 262/1000: max V1 for g of 1.31131 is 29.768
# No 2nd peak found
# --------------------------------
# Iter 263/1000: max V1 for g of 1.31632 is 29.905
# No 2nd peak found
# --------------------------------
# Iter 264/1000: max V1 for g of 1.32132 is 29.909
# No 2nd peak found
# --------------------------------
# Iter 265/1000: max V1 for g of 1.32633 is 29.978
# No 2nd peak found
# --------------------------------
# Iter 266/1000: max V1 for g of 1.33133 is 30.048
# No 2nd peak found
# --------------------------------
# Iter 267/1000: max V1 for g of 1.33634 is 30.116
# No 2nd peak found
# --------------------------------
# Iter 268/1000: max V1 for g of 1.34134 is 30.185
# No 2nd peak found
# --------------------------------
# Iter 269/1000: max V1 for g of 1.34635 is 30.253
# No 2nd peak found
# --------------------------------
# Iter 270/1000: max V1 for g of 1.35135 is 30.321
# No 2nd peak found
# --------------------------------
# Iter 271/1000: max V1 for g of 1.35636 is 30.388
# No 2nd peak found
# --------------------------------
# Iter 272/1000: max V1 for g of 1.36136 is 30.455
# No 2nd peak found
# --------------------------------
# Iter 273/1000: max V1 for g of 1.36637 is 30.522
# No 2nd peak found
# --------------------------------
# Iter 274/1000: max V1 for g of 1.37137 is 30.588
# No 2nd peak found
# --------------------------------
# Iter 275/1000: max V1 for g of 1.37638 is 30.654
# No 2nd peak found
# --------------------------------
# Iter 276/1000: max V1 for g of 1.38138 is 30.719
# No 2nd peak found
# --------------------------------
# Iter 277/1000: max V1 for g of 1.38639 is 30.785
# No 2nd peak found
# --------------------------------
# Iter 278/1000: max V1 for g of 1.39139 is 30.850
# No 2nd peak found
# --------------------------------
# Iter 279/1000: max V1 for g of 1.39640 is 30.914
# No 2nd peak found
# --------------------------------
# Iter 280/1000: max V1 for g of 1.40140 is 30.978
# No 2nd peak found
# --------------------------------
# Iter 281/1000: max V1 for g of 1.40641 is 31.042
# No 2nd peak found
# --------------------------------
# Iter 282/1000: max V1 for g of 1.41141 is 31.106
# No 2nd peak found
# --------------------------------
# Iter 283/1000: max V1 for g of 1.41642 is 31.169
# No 2nd peak found
# --------------------------------
# Iter 284/1000: max V1 for g of 1.42142 is 31.232
# No 2nd peak found
# --------------------------------
# Iter 285/1000: max V1 for g of 1.42643 is 31.294
# No 2nd peak found
# --------------------------------
# Iter 286/1000: max V1 for g of 1.43143 is 31.357
# No 2nd peak found
# --------------------------------
# Iter 287/1000: max V1 for g of 1.43644 is 31.418
# No 2nd peak found
# --------------------------------
# Iter 288/1000: max V1 for g of 1.44144 is 31.480
# No 2nd peak found
# --------------------------------
# Iter 289/1000: max V1 for g of 1.44645 is 31.541
# No 2nd peak found
# --------------------------------
# Iter 290/1000: max V1 for g of 1.45145 is 31.602
# No 2nd peak found
# --------------------------------
# Iter 291/1000: max V1 for g of 1.45646 is 31.663
# No 2nd peak found
# --------------------------------
# Iter 292/1000: max V1 for g of 1.46146 is 31.723
# No 2nd peak found
# --------------------------------
# Iter 293/1000: max V1 for g of 1.46647 is 31.783
# No 2nd peak found
# --------------------------------
# Iter 294/1000: max V1 for g of 1.47147 is 31.843
# No 2nd peak found
# --------------------------------
# Iter 295/1000: max V1 for g of 1.47648 is 31.902
# No 2nd peak found
# --------------------------------
# Iter 296/1000: max V1 for g of 1.48148 is 31.962
# No 2nd peak found
# --------------------------------
# Iter 297/1000: max V1 for g of 1.48649 is 32.020
# No 2nd peak found
# --------------------------------
# Iter 298/1000: max V1 for g of 1.49149 is 32.079
# No 2nd peak found
# --------------------------------
# Iter 299/1000: max V1 for g of 1.49650 is 32.137
# No 2nd peak found
# --------------------------------
# Iter 300/1000: max V1 for g of 1.50150 is 32.195
# No 2nd peak found
# --------------------------------
# Iter 301/1000: max V1 for g of 1.50651 is 32.253
# No 2nd peak found
# --------------------------------
# Iter 302/1000: max V1 for g of 1.51151 is 32.310
# No 2nd peak found
# --------------------------------
# Iter 303/1000: max V1 for g of 1.51652 is 32.367
# No 2nd peak found
# --------------------------------
# Iter 304/1000: max V1 for g of 1.52152 is 32.424
# No 2nd peak found
# --------------------------------
# Iter 305/1000: max V1 for g of 1.52653 is 32.480
# No 2nd peak found
# --------------------------------
# Iter 306/1000: max V1 for g of 1.53153 is 32.537
# No 2nd peak found
# --------------------------------
# Iter 307/1000: max V1 for g of 1.53654 is 32.593
# No 2nd peak found
# --------------------------------
# Iter 308/1000: max V1 for g of 1.54154 is 32.648
# No 2nd peak found
# --------------------------------
# Iter 309/1000: max V1 for g of 1.54655 is 32.704
# No 2nd peak found
# --------------------------------
# Iter 310/1000: max V1 for g of 1.55155 is 32.759
# No 2nd peak found
# --------------------------------
# Iter 311/1000: max V1 for g of 1.55656 is 32.814
# No 2nd peak found
# --------------------------------
# Iter 312/1000: max V1 for g of 1.56156 is 32.868
# No 2nd peak found
# --------------------------------
# Iter 313/1000: max V1 for g of 1.56657 is 32.923
# No 2nd peak found
# --------------------------------
# Iter 314/1000: max V1 for g of 1.57157 is 32.977
# No 2nd peak found
# --------------------------------
# Iter 315/1000: max V1 for g of 1.57658 is 33.031
# No 2nd peak found
# --------------------------------
# Iter 316/1000: max V1 for g of 1.58158 is 33.084
# No 2nd peak found
# --------------------------------
# Iter 317/1000: max V1 for g of 1.58659 is 33.137
# No 2nd peak found
# --------------------------------
# Iter 318/1000: max V1 for g of 1.59159 is 33.191
# No 2nd peak found
# --------------------------------
# Iter 319/1000: max V1 for g of 1.59660 is 33.243
# No 2nd peak found
# --------------------------------
# Iter 320/1000: max V1 for g of 1.60160 is 33.296
# No 2nd peak found
# --------------------------------
# Iter 321/1000: max V1 for g of 1.60661 is 33.348
# No 2nd peak found
# --------------------------------
# Iter 322/1000: max V1 for g of 1.61161 is 33.400
# No 2nd peak found
# --------------------------------
# Iter 323/1000: max V1 for g of 1.61662 is 33.452
# No 2nd peak found
# --------------------------------
# Iter 324/1000: max V1 for g of 1.62162 is 33.504
# No 2nd peak found
# --------------------------------
# Iter 325/1000: max V1 for g of 1.62663 is 33.555
# No 2nd peak found
# --------------------------------
# Iter 326/1000: max V1 for g of 1.63163 is 33.606
# No 2nd peak found
# --------------------------------
# Iter 327/1000: max V1 for g of 1.63664 is 33.657
# No 2nd peak found
# --------------------------------
# Iter 328/1000: max V1 for g of 1.64164 is 33.707
# No 2nd peak found
# --------------------------------
# Iter 329/1000: max V1 for g of 1.64665 is 33.758
# No 2nd peak found
# --------------------------------
# Iter 330/1000: max V1 for g of 1.65165 is 33.808
# No 2nd peak found
# --------------------------------
# Iter 331/1000: max V1 for g of 1.65666 is 33.858
# No 2nd peak found
# --------------------------------
# Iter 332/1000: max V1 for g of 1.66166 is 33.907
# No 2nd peak found
# --------------------------------
# Iter 333/1000: max V1 for g of 1.66667 is 33.957
# No 2nd peak found
# --------------------------------
# Iter 334/1000: max V1 for g of 1.67167 is 34.006
# No 2nd peak found
# --------------------------------
# Iter 335/1000: max V1 for g of 1.67668 is 34.055
# No 2nd peak found
# --------------------------------
# Iter 336/1000: max V1 for g of 1.68168 is 34.104
# No 2nd peak found
# --------------------------------
# Iter 337/1000: max V1 for g of 1.68669 is 34.152
# No 2nd peak found
# --------------------------------
# Iter 338/1000: max V1 for g of 1.69169 is 34.201
# No 2nd peak found
# --------------------------------
# Iter 339/1000: max V1 for g of 1.69670 is 34.249
# No 2nd peak found
# --------------------------------
# Iter 340/1000: max V1 for g of 1.70170 is 34.296
# No 2nd peak found
# --------------------------------
# Iter 341/1000: max V1 for g of 1.70671 is 34.344
# No 2nd peak found
# --------------------------------
# Iter 342/1000: max V1 for g of 1.71171 is 34.392
# No 2nd peak found
# --------------------------------
# Iter 343/1000: max V1 for g of 1.71672 is 34.439
# No 2nd peak found
# --------------------------------
# Iter 344/1000: max V1 for g of 1.72172 is 34.539
# No 2nd peak found
# --------------------------------
# Iter 345/1000: max V1 for g of 1.72673 is 34.533
# No 2nd peak found
# --------------------------------
# Iter 346/1000: max V1 for g of 1.73173 is 34.632
# No 2nd peak found
# --------------------------------
# Iter 347/1000: max V1 for g of 1.73674 is 34.678
# No 2nd peak found
# --------------------------------
# Iter 348/1000: max V1 for g of 1.74174 is 34.724
# No 2nd peak found
# --------------------------------
# Iter 349/1000: max V1 for g of 1.74675 is 34.718
# No 2nd peak found
# --------------------------------
# Iter 350/1000: max V1 for g of 1.75175 is 34.816
# No 2nd peak found
# --------------------------------
# Iter 351/1000: max V1 for g of 1.75676 is 34.861
# No 2nd peak found
# --------------------------------
# Iter 352/1000: max V1 for g of 1.76176 is 34.907
# No 2nd peak found
# --------------------------------
# Iter 353/1000: max V1 for g of 1.76677 is 34.952
# No 2nd peak found
# --------------------------------
# Iter 354/1000: max V1 for g of 1.77177 is 34.996
# No 2nd peak found
# --------------------------------
# Iter 355/1000: max V1 for g of 1.77678 is 34.989
# No 2nd peak found
# --------------------------------
# Iter 356/1000: max V1 for g of 1.78178 is 35.085
# No 2nd peak found
# --------------------------------
# Iter 357/1000: max V1 for g of 1.78679 is 35.078
# No 2nd peak found
# --------------------------------
# Iter 358/1000: max V1 for g of 1.79179 is 35.174
# No 2nd peak found
# --------------------------------
# Iter 359/1000: max V1 for g of 1.79680 is 35.166
# No 2nd peak found
# --------------------------------
# Iter 360/1000: max V1 for g of 1.80180 is 35.210
# No 2nd peak found
# --------------------------------
# Iter 361/1000: max V1 for g of 1.80681 is 35.254
# No 2nd peak found
# --------------------------------
# Iter 362/1000: max V1 for g of 1.81181 is 35.348
# No 2nd peak found
# --------------------------------
# Iter 363/1000: max V1 for g of 1.81682 is 35.391
# No 2nd peak found
# --------------------------------
# Iter 364/1000: max V1 for g of 1.82182 is 35.434
# No 2nd peak found
# --------------------------------
# Iter 365/1000: max V1 for g of 1.82683 is 35.426
# No 2nd peak found
# --------------------------------
# Iter 366/1000: max V1 for g of 1.83183 is 35.519
# No 2nd peak found
# --------------------------------
# Iter 367/1000: max V1 for g of 1.83684 is 35.511
# No 2nd peak found
# --------------------------------
# Iter 368/1000: max V1 for g of 1.84184 is 35.604
# No 2nd peak found
# --------------------------------
# Iter 369/1000: max V1 for g of 1.84685 is 35.646
# No 2nd peak found
# --------------------------------
# Iter 370/1000: max V1 for g of 1.85185 is 35.688
# No 2nd peak found
# --------------------------------
# Iter 371/1000: max V1 for g of 1.85686 is 35.729
# No 2nd peak found
# --------------------------------
# Iter 372/1000: max V1 for g of 1.86186 is 35.771
# No 2nd peak found
# --------------------------------
# Iter 373/1000: max V1 for g of 1.86687 is 35.812
# No 2nd peak found
# --------------------------------
# Iter 374/1000: max V1 for g of 1.87187 is 35.853
# No 2nd peak found
# --------------------------------
# Iter 375/1000: max V1 for g of 1.87688 is 35.894
# No 2nd peak found
# --------------------------------
# Iter 376/1000: max V1 for g of 1.88188 is 35.935
# No 2nd peak found
# --------------------------------
# Iter 377/1000: max V1 for g of 1.88689 is 35.975
# No 2nd peak found
# --------------------------------
# Iter 378/1000: max V1 for g of 1.89189 is 36.016
# No 2nd peak found
# --------------------------------
# Iter 379/1000: max V1 for g of 1.89690 is 36.056
# No 2nd peak found
# --------------------------------
# Iter 380/1000: max V1 for g of 1.90190 is 36.047
# No 2nd peak found
# --------------------------------
# Iter 381/1000: max V1 for g of 1.90691 is 36.136
# No 2nd peak found
# --------------------------------
# Iter 382/1000: max V1 for g of 1.91191 is 36.127
# No 2nd peak found
# --------------------------------
# Iter 383/1000: max V1 for g of 1.91692 is 36.167
# No 2nd peak found
# --------------------------------
# Iter 384/1000: max V1 for g of 1.92192 is 36.255
# No 2nd peak found
# --------------------------------
# Iter 385/1000: max V1 for g of 1.92693 is 36.246
# No 2nd peak found
# --------------------------------
# Iter 386/1000: max V1 for g of 1.93193 is 36.333
# No 2nd peak found
# --------------------------------
# Iter 387/1000: max V1 for g of 1.93694 is 36.324
# No 2nd peak found
# --------------------------------
# Iter 388/1000: max V1 for g of 1.94194 is 36.363
# No 2nd peak found
# --------------------------------
# Iter 389/1000: max V1 for g of 1.94695 is 36.401
# No 2nd peak found
# --------------------------------
# Iter 390/1000: max V1 for g of 1.95195 is 36.440
# No 2nd peak found
# --------------------------------
# Iter 391/1000: max V1 for g of 1.95696 is 36.478
# No 2nd peak found
# --------------------------------
# Iter 392/1000: max V1 for g of 1.96196 is 36.517
# No 2nd peak found
# --------------------------------
# Iter 393/1000: max V1 for g of 1.96697 is 36.602
# No 2nd peak found
# --------------------------------
# Iter 394/1000: max V1 for g of 1.97197 is 36.593
# No 2nd peak found
# --------------------------------
# Iter 395/1000: max V1 for g of 1.97698 is 36.630
# No 2nd peak found
# --------------------------------
# Iter 396/1000: max V1 for g of 1.98198 is 36.715
# No 2nd peak found
# --------------------------------
# Iter 397/1000: max V1 for g of 1.98699 is 36.706
# No 2nd peak found
# --------------------------------
# Iter 398/1000: max V1 for g of 1.99199 is 36.743
# No 2nd peak found
# --------------------------------
# Iter 399/1000: max V1 for g of 1.99700 is 36.780
# No 2nd peak found
# --------------------------------
# Iter 400/1000: max V1 for g of 2.00200 is 36.864
# No 2nd peak found
# --------------------------------
# Iter 401/1000: max V1 for g of 2.00701 is 36.854
# No 2nd peak found
# --------------------------------
# Iter 402/1000: max V1 for g of 2.01201 is 36.937
# No 2nd peak found
# --------------------------------
# Iter 403/1000: max V1 for g of 2.01702 is 36.927
# No 2nd peak found
# --------------------------------
# Iter 404/1000: max V1 for g of 2.02202 is 37.010
# No 2nd peak found
# --------------------------------
# Iter 405/1000: max V1 for g of 2.02703 is 37.000
# No 2nd peak found
# --------------------------------
# Iter 406/1000: max V1 for g of 2.03203 is 37.036
# No 2nd peak found
# --------------------------------
# Iter 407/1000: max V1 for g of 2.03704 is 37.072
# No 2nd peak found
# --------------------------------
# Iter 408/1000: max V1 for g of 2.04204 is 37.154
# No 2nd peak found
# --------------------------------
# Iter 409/1000: max V1 for g of 2.04705 is 37.144
# No 2nd peak found
# --------------------------------
# Iter 410/1000: max V1 for g of 2.05205 is 37.225
# No 2nd peak found
# --------------------------------
# Iter 411/1000: max V1 for g of 2.05706 is 37.215
# No 2nd peak found
# --------------------------------
# Iter 412/1000: max V1 for g of 2.06206 is 37.250
# No 2nd peak found
# --------------------------------
# Iter 413/1000: max V1 for g of 2.06707 is 37.285
# No 2nd peak found
# --------------------------------
# Iter 414/1000: max V1 for g of 2.07207 is 37.366
# No 2nd peak found
# --------------------------------
# Iter 415/1000: max V1 for g of 2.07708 is 37.401
# No 2nd peak found
# --------------------------------
# Iter 416/1000: max V1 for g of 2.08208 is 37.435
# No 2nd peak found
# --------------------------------
# Iter 417/1000: max V1 for g of 2.08709 is 37.470
# No 2nd peak found
# --------------------------------
# Iter 418/1000: max V1 for g of 2.09209 is 37.459
# No 2nd peak found
# --------------------------------
# Iter 419/1000: max V1 for g of 2.09710 is 37.494
# No 2nd peak found
# --------------------------------
# Iter 420/1000: max V1 for g of 2.10210 is 37.528
# No 2nd peak found
# --------------------------------
# Iter 421/1000: max V1 for g of 2.10711 is 37.562
# No 2nd peak found
# --------------------------------
# Iter 422/1000: max V1 for g of 2.11211 is 37.596
# No 2nd peak found
# --------------------------------
# Iter 423/1000: max V1 for g of 2.11712 is 37.630
# No 2nd peak found
# --------------------------------
# Iter 424/1000: max V1 for g of 2.12212 is 37.708
# No 2nd peak found
# --------------------------------
# Iter 425/1000: max V1 for g of 2.12713 is 37.697
# No 2nd peak found
# --------------------------------
# Iter 426/1000: max V1 for g of 2.13213 is 37.730
# No 2nd peak found
# --------------------------------
# Iter 427/1000: max V1 for g of 2.13714 is 37.808
# No 2nd peak found
# --------------------------------
# Iter 428/1000: max V1 for g of 2.14214 is 37.797
# No 2nd peak found
# --------------------------------
# Iter 429/1000: max V1 for g of 2.14715 is 37.874
# No 2nd peak found
# --------------------------------
# Iter 430/1000: max V1 for g of 2.15215 is 37.863
# No 2nd peak found
# --------------------------------
# Iter 431/1000: max V1 for g of 2.15716 is 37.896
# No 2nd peak found
# --------------------------------
# Iter 432/1000: max V1 for g of 2.16216 is 37.928
# No 2nd peak found
# --------------------------------
# Iter 433/1000: max V1 for g of 2.16717 is 38.005
# No 2nd peak found
# --------------------------------
# Iter 434/1000: max V1 for g of 2.17217 is 37.993
# No 2nd peak found
# --------------------------------
# Iter 435/1000: max V1 for g of 2.17718 is 38.026
# No 2nd peak found
# --------------------------------
# Iter 436/1000: max V1 for g of 2.18218 is 38.058
# No 2nd peak found
# --------------------------------
# Iter 437/1000: max V1 for g of 2.18719 is 38.090
# No 2nd peak found
# --------------------------------
# Iter 438/1000: max V1 for g of 2.19219 is 38.122
# No 2nd peak found
# --------------------------------
# Iter 439/1000: max V1 for g of 2.19720 is 38.154
# No 2nd peak found
# --------------------------------
# Iter 440/1000: max V1 for g of 2.20220 is 38.229
# No 2nd peak found
# --------------------------------
# Iter 441/1000: max V1 for g of 2.20721 is 38.217
# No 2nd peak found
# --------------------------------
# Iter 442/1000: max V1 for g of 2.21221 is 38.249
# No 2nd peak found
# --------------------------------
# Iter 443/1000: max V1 for g of 2.21722 is 38.323
# No 2nd peak found
# --------------------------------
# Iter 444/1000: max V1 for g of 2.22222 is 38.311
# No 2nd peak found
# --------------------------------
# Iter 445/1000: max V1 for g of 2.22723 is 38.385
# No 2nd peak found
# --------------------------------
# Iter 446/1000: max V1 for g of 2.23223 is 38.416
# No 2nd peak found
# --------------------------------
# Iter 447/1000: max V1 for g of 2.23724 is 38.447
# No 2nd peak found
# --------------------------------
# Iter 448/1000: max V1 for g of 2.24224 is 38.478
# No 2nd peak found
# --------------------------------
# Iter 449/1000: max V1 for g of 2.24725 is 38.466
# No 2nd peak found
# --------------------------------
# Iter 450/1000: max V1 for g of 2.25225 is 38.539
# No 2nd peak found
# --------------------------------
# Iter 451/1000: max V1 for g of 2.25726 is 38.527
# No 2nd peak found
# --------------------------------
# Iter 452/1000: max V1 for g of 2.26226 is 38.557
# No 2nd peak found
# --------------------------------
# Iter 453/1000: max V1 for g of 2.26727 is 38.588
# No 2nd peak found
# --------------------------------
# Iter 454/1000: max V1 for g of 2.27227 is 38.660
# No 2nd peak found
# --------------------------------
# Iter 455/1000: max V1 for g of 2.27728 is 38.690
# No 2nd peak found
# --------------------------------
# Iter 456/1000: max V1 for g of 2.28228 is 38.678
# No 2nd peak found
# --------------------------------
# Iter 457/1000: max V1 for g of 2.28729 is 38.707
# No 2nd peak found
# --------------------------------
# Iter 458/1000: max V1 for g of 2.29229 is 38.737
# No 2nd peak found
# --------------------------------
# Iter 459/1000: max V1 for g of 2.29730 is 38.767
# No 2nd peak found
# --------------------------------
# Iter 460/1000: max V1 for g of 2.30230 is 38.838
# No 2nd peak found
# --------------------------------
# Iter 461/1000: max V1 for g of 2.30731 is 38.867
# No 2nd peak found
# --------------------------------
# Iter 462/1000: max V1 for g of 2.31231 is 38.855
# No 2nd peak found
# --------------------------------
# Iter 463/1000: max V1 for g of 2.31732 is 38.884
# No 2nd peak found
# --------------------------------
# Iter 464/1000: max V1 for g of 2.32232 is 38.913
# No 2nd peak found
# --------------------------------
# Iter 465/1000: max V1 for g of 2.32733 is 38.942
# No 2nd peak found
# --------------------------------
# Iter 466/1000: max V1 for g of 2.33233 is 39.012
# No 2nd peak found
# --------------------------------
# Iter 467/1000: max V1 for g of 2.33734 is 39.041
# No 2nd peak found
# --------------------------------
# Iter 468/1000: max V1 for g of 2.34234 is 39.069
# No 2nd peak found
# --------------------------------
# Iter 469/1000: max V1 for g of 2.34735 is 39.057
# No 2nd peak found
# --------------------------------
# Iter 470/1000: max V1 for g of 2.35235 is 39.126
# No 2nd peak found
# --------------------------------
# Iter 471/1000: max V1 for g of 2.35736 is 39.154
# No 2nd peak found
# --------------------------------
# Iter 472/1000: max V1 for g of 2.36236 is 39.183
# No 2nd peak found
# --------------------------------
# Iter 473/1000: max V1 for g of 2.36737 is 39.170
# No 2nd peak found
# --------------------------------
# Iter 474/1000: max V1 for g of 2.37237 is 39.239
# No 2nd peak found
# --------------------------------
# Iter 475/1000: max V1 for g of 2.37738 is 39.226
# No 2nd peak found
# --------------------------------
# Iter 476/1000: max V1 for g of 2.38238 is 39.254
# No 2nd peak found
# --------------------------------
# Iter 477/1000: max V1 for g of 2.38739 is 39.322
# No 2nd peak found
# --------------------------------
# Iter 478/1000: max V1 for g of 2.39239 is 39.350
# No 2nd peak found
# --------------------------------
# Iter 479/1000: max V1 for g of 2.39740 is 39.337
# No 2nd peak found
# --------------------------------
# Iter 480/1000: max V1 for g of 2.40240 is 39.365
# No 2nd peak found
# --------------------------------
# ...
# No 2nd peak found
# --------------------------------
# Iter 842/1000: max V1 for g of 4.20921 is 45.457
# No 2nd peak found
# --------------------------------
# Iter 843/1000: max V1 for g of 4.21421 is 45.467
# No 2nd peak found
# --------------------------------
# Iter 844/1000: max V1 for g of 4.21922 is 45.478
# No 2nd peak found
# --------------------------------
# Iter 845/1000: max V1 for g of 4.22422 is 45.488
# No 2nd peak found
# --------------------------------
# Iter 846/1000: max V1 for g of 4.22923 is 45.498
# No 2nd peak found
# --------------------------------
# Iter 847/1000: max V1 for g of 4.23423 is 45.509
# No 2nd peak found
# --------------------------------
# Iter 848/1000: max V1 for g of 4.23924 is 45.519
# No 2nd peak found
# --------------------------------
# Iter 849/1000: max V1 for g of 4.24424 is 45.529
# No 2nd peak found
# --------------------------------
# Iter 850/1000: max V1 for g of 4.24925 is 45.539
# No 2nd peak found
# --------------------------------
# Iter 851/1000: max V1 for g of 4.25425 is 45.550
# No 2nd peak found
# --------------------------------
# Iter 852/1000: max V1 for g of 4.25926 is 45.560
# No 2nd peak found
# --------------------------------
# Iter 853/1000: max V1 for g of 4.26426 is 45.570
# No 2nd peak found
# --------------------------------
# Iter 854/1000: max V1 for g of 4.26927 is 45.580
# No 2nd peak found
# --------------------------------
# Iter 855/1000: max V1 for g of 4.27427 is 45.590
# No 2nd peak found
# --------------------------------
# Iter 856/1000: max V1 for g of 4.27928 is 45.600
# No 2nd peak found
# --------------------------------
# Iter 857/1000: max V1 for g of 4.28428 is 45.610
# No 2nd peak found
# --------------------------------
# Iter 858/1000: max V1 for g of 4.28929 is 45.620
# No 2nd peak found
# --------------------------------
# Iter 859/1000: max V1 for g of 4.29429 is 45.630
# No 2nd peak found
# --------------------------------
# Iter 860/1000: max V1 for g of 4.29930 is 45.640
# No 2nd peak found
# --------------------------------
# Iter 861/1000: max V1 for g of 4.30430 is 45.650
# No 2nd peak found
# --------------------------------
# Iter 862/1000: max V1 for g of 4.30931 is 45.660
# No 2nd peak found
# --------------------------------
# Iter 863/1000: max V1 for g of 4.31431 is 45.670
# No 2nd peak found
# --------------------------------
# Iter 864/1000: max V1 for g of 4.31932 is 45.680
# No 2nd peak found
# --------------------------------
# Iter 865/1000: max V1 for g of 4.32432 is 45.690
# No 2nd peak found
# --------------------------------
# Iter 866/1000: max V1 for g of 4.32933 is 45.700
# No 2nd peak found
# --------------------------------
# Iter 867/1000: max V1 for g of 4.33433 is 45.710
# No 2nd peak found
# --------------------------------
# Iter 868/1000: max V1 for g of 4.33934 is 45.720
# No 2nd peak found
# --------------------------------
# Iter 869/1000: max V1 for g of 4.34434 is 45.729
# No 2nd peak found
# --------------------------------
# Iter 870/1000: max V1 for g of 4.34935 is 45.739
# No 2nd peak found
# --------------------------------
# Iter 871/1000: max V1 for g of 4.35435 is 45.749
# No 2nd peak found
# --------------------------------
# Iter 872/1000: max V1 for g of 4.35936 is 45.759
# No 2nd peak found
# --------------------------------
# Iter 873/1000: max V1 for g of 4.36436 is 45.768
# No 2nd peak found
# --------------------------------
# Iter 874/1000: max V1 for g of 4.36937 is 45.778
# No 2nd peak found
# --------------------------------
# Iter 875/1000: max V1 for g of 4.37437 is 45.788
# No 2nd peak found
# --------------------------------
# Iter 876/1000: max V1 for g of 4.37938 is 45.798
# No 2nd peak found
# --------------------------------
# Iter 877/1000: max V1 for g of 4.38438 is 45.807
# No 2nd peak found
# --------------------------------
# Iter 878/1000: max V1 for g of 4.38939 is 45.817
# No 2nd peak found
# --------------------------------
# Iter 879/1000: max V1 for g of 4.39439 is 45.826
# No 2nd peak found
# --------------------------------
# Iter 880/1000: max V1 for g of 4.39940 is 45.836
# No 2nd peak found
# --------------------------------
# Iter 881/1000: max V1 for g of 4.40440 is 45.846
# No 2nd peak found
# --------------------------------
# Iter 882/1000: max V1 for g of 4.40941 is 45.855
# No 2nd peak found
# --------------------------------
# Iter 883/1000: max V1 for g of 4.41441 is 45.865
# No 2nd peak found
# --------------------------------
# Iter 884/1000: max V1 for g of 4.41942 is 45.874
# No 2nd peak found
# --------------------------------
# Iter 885/1000: max V1 for g of 4.42442 is 45.884
# No 2nd peak found
# --------------------------------
# Iter 886/1000: max V1 for g of 4.42943 is 45.893
# No 2nd peak found
# --------------------------------
# Iter 887/1000: max V1 for g of 4.43443 is 45.903
# No 2nd peak found
# --------------------------------
# Iter 888/1000: max V1 for g of 4.43944 is 45.912
# No 2nd peak found
# --------------------------------
# Iter 889/1000: max V1 for g of 4.44444 is 45.922
# No 2nd peak found
# --------------------------------
# Iter 890/1000: max V1 for g of 4.44945 is 45.931
# No 2nd peak found
# --------------------------------
# Iter 891/1000: max V1 for g of 4.45445 is 45.940
# No 2nd peak found
# --------------------------------
# Iter 892/1000: max V1 for g of 4.45946 is 45.950
# No 2nd peak found
# --------------------------------
# Iter 893/1000: max V1 for g of 4.46446 is 45.959
# No 2nd peak found
# --------------------------------
# Iter 894/1000: max V1 for g of 4.46947 is 45.968
# No 2nd peak found
# --------------------------------
# Iter 895/1000: max V1 for g of 4.47447 is 45.978
# No 2nd peak found
# --------------------------------
# Iter 896/1000: max V1 for g of 4.47948 is 45.987
# No 2nd peak found
# --------------------------------
# Iter 897/1000: max V1 for g of 4.48448 is 45.996
# No 2nd peak found
# --------------------------------
# Iter 898/1000: max V1 for g of 4.48949 is 46.005
# No 2nd peak found
# --------------------------------
# Iter 899/1000: max V1 for g of 4.49449 is 46.015
# No 2nd peak found
# --------------------------------
# Iter 900/1000: max V1 for g of 4.49950 is 46.024
# No 2nd peak found
# --------------------------------
# Iter 901/1000: max V1 for g of 4.50450 is 46.033
# No 2nd peak found
# --------------------------------
# Iter 902/1000: max V1 for g of 4.50951 is 46.042
# No 2nd peak found
# --------------------------------
# Iter 903/1000: max V1 for g of 4.51451 is 46.051
# No 2nd peak found
# --------------------------------
# Iter 904/1000: max V1 for g of 4.51952 is 46.061
# No 2nd peak found
# --------------------------------
# Iter 905/1000: max V1 for g of 4.52452 is 46.070
# No 2nd peak found
# --------------------------------
# Iter 906/1000: max V1 for g of 4.52953 is 46.079
# No 2nd peak found
# --------------------------------
# Iter 907/1000: max V1 for g of 4.53453 is 46.088
# No 2nd peak found
# --------------------------------
# Iter 908/1000: max V1 for g of 4.53954 is 46.097
# No 2nd peak found
# --------------------------------
# Iter 909/1000: max V1 for g of 4.54454 is 46.106
# No 2nd peak found
# --------------------------------
# Iter 910/1000: max V1 for g of 4.54955 is 46.115
# No 2nd peak found
# --------------------------------
# Iter 911/1000: max V1 for g of 4.55455 is 46.124
# No 2nd peak found
# --------------------------------
# Iter 912/1000: max V1 for g of 4.55956 is 46.133
# No 2nd peak found
# --------------------------------
# Iter 913/1000: max V1 for g of 4.56456 is 46.142
# No 2nd peak found
# --------------------------------
# Iter 914/1000: max V1 for g of 4.56957 is 46.151
# No 2nd peak found
# --------------------------------
# Iter 915/1000: max V1 for g of 4.57457 is 46.160
# No 2nd peak found
# --------------------------------
# Iter 916/1000: max V1 for g of 4.57958 is 46.169
# No 2nd peak found
# --------------------------------
# Iter 917/1000: max V1 for g of 4.58458 is 46.178
# No 2nd peak found
# --------------------------------
# Iter 918/1000: max V1 for g of 4.58959 is 46.187
# No 2nd peak found
# --------------------------------
# Iter 919/1000: max V1 for g of 4.59459 is 46.195
# No 2nd peak found
# --------------------------------
# Iter 920/1000: max V1 for g of 4.59960 is 46.204
# No 2nd peak found
# --------------------------------
# Iter 921/1000: max V1 for g of 4.60460 is 46.213
# No 2nd peak found
# --------------------------------
# Iter 922/1000: max V1 for g of 4.60961 is 46.222
# No 2nd peak found
# --------------------------------
# Iter 923/1000: max V1 for g of 4.61461 is 46.231
# No 2nd peak found
# --------------------------------
# Iter 924/1000: max V1 for g of 4.61962 is 46.240
# No 2nd peak found
# --------------------------------
# Iter 925/1000: max V1 for g of 4.62462 is 46.248
# No 2nd peak found
# --------------------------------
# Iter 926/1000: max V1 for g of 4.62963 is 46.257
# No 2nd peak found
# --------------------------------
# Iter 927/1000: max V1 for g of 4.63463 is 46.266
# No 2nd peak found
# --------------------------------
# Iter 928/1000: max V1 for g of 4.63964 is 46.274
# No 2nd peak found
# --------------------------------
# Iter 929/1000: max V1 for g of 4.64464 is 46.283
# No 2nd peak found
# --------------------------------
# Iter 930/1000: max V1 for g of 4.64965 is 46.292
# No 2nd peak found
# --------------------------------
# Iter 931/1000: max V1 for g of 4.65465 is 46.301
# No 2nd peak found
# --------------------------------
# Iter 932/1000: max V1 for g of 4.65966 is 46.309
# No 2nd peak found
# --------------------------------
# Iter 933/1000: max V1 for g of 4.66466 is 46.318
# No 2nd peak found
# --------------------------------
# Iter 934/1000: max V1 for g of 4.66967 is 46.326
# No 2nd peak found
# --------------------------------
# Iter 935/1000: max V1 for g of 4.67467 is 46.335
# No 2nd peak found
# --------------------------------
# Iter 936/1000: max V1 for g of 4.67968 is 46.344
# No 2nd peak found
# --------------------------------
# Iter 937/1000: max V1 for g of 4.68468 is 46.352
# No 2nd peak found
# --------------------------------
# Iter 938/1000: max V1 for g of 4.68969 is 46.361
# No 2nd peak found
# --------------------------------
# Iter 939/1000: max V1 for g of 4.69469 is 46.369
# No 2nd peak found
# --------------------------------
# Iter 940/1000: max V1 for g of 4.69970 is 46.378
# No 2nd peak found
# --------------------------------
# Iter 941/1000: max V1 for g of 4.70470 is 46.386
# No 2nd peak found
# --------------------------------
# Iter 942/1000: max V1 for g of 4.70971 is 46.395
# No 2nd peak found
# --------------------------------
# Iter 943/1000: max V1 for g of 4.71471 is 46.403
# No 2nd peak found
# --------------------------------
# Iter 944/1000: max V1 for g of 4.71972 is 46.412
# No 2nd peak found
# --------------------------------
# Iter 945/1000: max V1 for g of 4.72472 is 46.420
# No 2nd peak found
# --------------------------------
# Iter 946/1000: max V1 for g of 4.72973 is 46.428
# No 2nd peak found
# --------------------------------
# Iter 947/1000: max V1 for g of 4.73473 is 46.437
# No 2nd peak found
# --------------------------------
# Iter 948/1000: max V1 for g of 4.73974 is 46.445
# No 2nd peak found
# --------------------------------
# Iter 949/1000: max V1 for g of 4.74474 is 46.454
# No 2nd peak found
# --------------------------------
# Iter 950/1000: max V1 for g of 4.74975 is 46.462
# No 2nd peak found
# --------------------------------
# Iter 951/1000: max V1 for g of 4.75475 is 46.470
# No 2nd peak found
# --------------------------------
# Iter 952/1000: max V1 for g of 4.75976 is 46.479
# No 2nd peak found
# --------------------------------
# Iter 953/1000: max V1 for g of 4.76476 is 46.487
# No 2nd peak found
# --------------------------------
# Iter 954/1000: max V1 for g of 4.76977 is 46.495
# No 2nd peak found
# --------------------------------
# Iter 955/1000: max V1 for g of 4.77477 is 46.504
# No 2nd peak found
# --------------------------------
# Iter 956/1000: max V1 for g of 4.77978 is 46.512
# No 2nd peak found
# --------------------------------
# Iter 957/1000: max V1 for g of 4.78478 is 46.520
# No 2nd peak found
# --------------------------------
# Iter 958/1000: max V1 for g of 4.78979 is 46.528
# No 2nd peak found
# --------------------------------
# Iter 959/1000: max V1 for g of 4.79479 is 46.536
# No 2nd peak found
# --------------------------------
# Iter 960/1000: max V1 for g of 4.79980 is 46.545
# No 2nd peak found
# --------------------------------
# Iter 961/1000: max V1 for g of 4.80480 is 46.553
# No 2nd peak found
# --------------------------------
# Iter 962/1000: max V1 for g of 4.80981 is 46.561
# No 2nd peak found
# --------------------------------
# Iter 963/1000: max V1 for g of 4.81481 is 46.569
# No 2nd peak found
# --------------------------------
# Iter 964/1000: max V1 for g of 4.81982 is 46.577
# No 2nd peak found
# --------------------------------
# Iter 965/1000: max V1 for g of 4.82482 is 46.585
# No 2nd peak found
# --------------------------------
# Iter 966/1000: max V1 for g of 4.82983 is 46.593
# No 2nd peak found
# --------------------------------
# Iter 967/1000: max V1 for g of 4.83483 is 46.602
# No 2nd peak found
# --------------------------------
# Iter 968/1000: max V1 for g of 4.83984 is 46.610
# No 2nd peak found
# --------------------------------
# Iter 969/1000: max V1 for g of 4.84484 is 46.618
# No 2nd peak found
# --------------------------------
# Iter 970/1000: max V1 for g of 4.84985 is 46.626
# No 2nd peak found
# --------------------------------
# Iter 971/1000: max V1 for g of 4.85485 is 46.634
# No 2nd peak found
# --------------------------------
# Iter 972/1000: max V1 for g of 4.85986 is 46.642
# No 2nd peak found
# --------------------------------
# Iter 973/1000: max V1 for g of 4.86486 is 46.650
# No 2nd peak found
# --------------------------------
# Iter 974/1000: max V1 for g of 4.86987 is 46.658
# No 2nd peak found
# --------------------------------
# Iter 975/1000: max V1 for g of 4.87487 is 46.666
# No 2nd peak found
# --------------------------------
# Iter 976/1000: max V1 for g of 4.87988 is 46.674
# No 2nd peak found
# --------------------------------
# Iter 977/1000: max V1 for g of 4.88488 is 46.682
# No 2nd peak found
# --------------------------------
# Iter 978/1000: max V1 for g of 4.88989 is 46.689
# No 2nd peak found
# --------------------------------
# Iter 979/1000: max V1 for g of 4.89489 is 46.697
# No 2nd peak found
# --------------------------------
# Iter 980/1000: max V1 for g of 4.89990 is 46.705
# No 2nd peak found
# --------------------------------
# Iter 981/1000: max V1 for g of 4.90490 is 46.713
# No 2nd peak found
# --------------------------------
# Iter 982/1000: max V1 for g of 4.90991 is 46.721
# No 2nd peak found
# --------------------------------
# Iter 983/1000: max V1 for g of 4.91491 is 46.729
# No 2nd peak found
# --------------------------------
# Iter 984/1000: max V1 for g of 4.91992 is 46.737
# No 2nd peak found
# --------------------------------
# Iter 985/1000: max V1 for g of 4.92492 is 46.745
# No 2nd peak found
# --------------------------------
# Iter 986/1000: max V1 for g of 4.92993 is 46.752
# No 2nd peak found
# --------------------------------
# Iter 987/1000: max V1 for g of 4.93493 is 46.760
# No 2nd peak found
# --------------------------------
# Iter 988/1000: max V1 for g of 4.93994 is 46.768
# No 2nd peak found
# --------------------------------
# Iter 989/1000: max V1 for g of 4.94494 is 46.776
# No 2nd peak found
# --------------------------------
# Iter 990/1000: max V1 for g of 4.94995 is 46.783
# No 2nd peak found
# --------------------------------
# Iter 991/1000: max V1 for g of 4.95495 is 46.791
# No 2nd peak found
# --------------------------------
# Iter 992/1000: max V1 for g of 4.95996 is 46.799
# No 2nd peak found
# --------------------------------
# Iter 993/1000: max V1 for g of 4.96496 is 46.807
# No 2nd peak found
# --------------------------------
# Iter 994/1000: max V1 for g of 4.96997 is 46.814
# No 2nd peak found
# --------------------------------
# Iter 995/1000: max V1 for g of 4.97497 is 46.822
# No 2nd peak found
# --------------------------------
# Iter 996/1000: max V1 for g of 4.97998 is 46.830
# No 2nd peak found
# --------------------------------
# Iter 997/1000: max V1 for g of 4.98498 is 46.837
# No 2nd peak found
# --------------------------------
# Iter 998/1000: max V1 for g of 4.98999 is 46.845
# No 2nd peak found
# --------------------------------
# Iter 999/1000: max V1 for g of 4.99499 is 46.852
# No 2nd peak found
# --------------------------------
# Iter 1000/1000: max V1 for g of 5.00000 is 46.860
# No 2nd peak found
# --------------------------------

# %% [markdown]
# ## Questions to answer
# 1. Are g1 and g2 the same or different?
#    - I would assume the same
# 2. Are s1 and s2 the same?
#    - I would assume the same
# 3. Should V1 and V2 (and other ICs) be the same between the neurons?
#    - I would assume the same

# %%
print(halfway_point)
print(V1_vec[halfway_point])
print(V1_vec[halfway_point+1])
print(V1_vec[halfway_point+10])
print(V1_vec[halfway_point+100])
print(V1_vec[halfway_point+400])
# Out:
# 2500
# 0.2840848995576352
# 0.28408489955761573
# 0.2840848995574403
# 0.284084899555686
# 0.2840848995498383
